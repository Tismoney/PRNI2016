# %%
import Subsection as ss
# %matplotlib inline

# %%
grid_cv = ss.StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
eval_cv = ss.StratifiedKFold(n_splits=10, shuffle=True, random_state=1)

# %%
Sub = ss.Subsection_low(eval_cv=eval_cv, grid_cv=grid_cv)

# %%
Sub.init_data()

# %%
Sub.init_params(
            k_init          = 28,
            k_split         = 2,
            collect_n       = 10,
            size_dim        = 264,
            num_iteration   = 100,
            learning_rate   = 0.5,
            min_vec         = 4,
            max_porog       = 0)

# %%
Sub.get_result()
# Out:
# INIT	 SCORE: 0.532
# epoch # 14	 SCORE: 0.537	 DEL: 1
#
# epoch # 22	 SCORE: 0.552	 DEL: 1
#
# epoch # 28	 SCORE: 0.562	 DEL: 3
#
# epoch # 32	 SCORE: 0.565	 DEL: 1
#
# epoch # 38	 SCORE: 0.588	 DEL: 1
#
# epoch # 44	 SCORE: 0.593	 DEL: 6
#
#
# REAL SCORE: 0.45
# INIT	 SCORE: 0.487
# epoch # 5	 SCORE: 0.488	 DEL: 0
#
# epoch # 15	 SCORE: 0.496	 DEL: 4
#
# epoch # 24	 SCORE: 0.501	 DEL: 6
#
# epoch # 64	 SCORE: 0.508	 DEL: 1
#
#
# REAL SCORE: 0.3
# INIT	 SCORE: 0.424
# epoch # 11	 SCORE: 0.434	 DEL: 4
#
# epoch # 24	 SCORE: 0.438	 DEL: 4
#
# epoch # 32	 SCORE: 0.443	 DEL: 1
#
# epoch # 39	 SCORE: 0.455	 DEL: 1
#
# epoch # 43	 SCORE: 0.473	 DEL: 2
#
# epoch # 51	 SCORE: 0.498	 DEL: 2
#
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.524
# epoch # 47	 SCORE: 0.534	 DEL: 1
#
#
# REAL SCORE: 0.675
# INIT	 SCORE: 0.494
# epoch # 7	 SCORE: 0.539	 DEL: 0
#
# epoch # 10	 SCORE: 0.570	 DEL: 0
#
# epoch # 12	 SCORE: 0.571	 DEL: 2
#
# epoch # 15	 SCORE: 0.572	 DEL: 0
#
# epoch # 24	 SCORE: 0.583	 DEL: 3
#
# epoch # 30	 SCORE: 0.608	 DEL: 2
#
#
# REAL SCORE: 0.2
# INIT	 SCORE: 0.466
# epoch # 11	 SCORE: 0.468	 DEL: 1
#
# epoch # 18	 SCORE: 0.503	 DEL: 1
#
# epoch # 21	 SCORE: 0.508	 DEL: 2
#
# epoch # 27	 SCORE: 0.532	 DEL: 2
#
# epoch # 31	 SCORE: 0.537	 DEL: 3
#
# epoch # 32	 SCORE: 0.619	 DEL: 1
#
#
# REAL SCORE: 0.55
# INIT	 SCORE: 0.328
# epoch # 42	 SCORE: 0.333	 DEL: 2
#
# epoch # 49	 SCORE: 0.344	 DEL: 1
#
# epoch # 50	 SCORE: 0.355	 DEL: 3
#
# epoch # 52	 SCORE: 0.378	 DEL: 2
#
# epoch # 60	 SCORE: 0.422	 DEL: 1
#
# epoch # 62	 SCORE: 0.426	 DEL: 0
#
# epoch # 67	 SCORE: 0.437	 DEL: 0
#
# epoch # 69	 SCORE: 0.459	 DEL: 0
#
# epoch # 71	 SCORE: 0.484	 DEL: 0
#
# epoch # 73	 SCORE: 0.542	 DEL: 0
#
# epoch # 97	 SCORE: 0.547	 DEL: 1
#
#
# REAL SCORE: 0.325
# INIT	 SCORE: 0.504
# epoch # 13	 SCORE: 0.515	 DEL: 3
#
# epoch # 37	 SCORE: 0.519	 DEL: 2
#
# epoch # 44	 SCORE: 0.522	 DEL: 7
#
# epoch # 56	 SCORE: 0.544	 DEL: 2
#
# epoch # 57	 SCORE: 0.549	 DEL: 3
#
# epoch # 60	 SCORE: 0.550	 DEL: 0
#
# epoch # 61	 SCORE: 0.615	 DEL: 2
#
#
# REAL SCORE: 0.525
# INIT	 SCORE: 0.473
# epoch # 8	 SCORE: 0.477	 DEL: 1
#
# epoch # 20	 SCORE: 0.484	 DEL: 2
#
# epoch # 38	 SCORE: 0.488	 DEL: 3
#
#
# REAL SCORE: 0.425
# INIT	 SCORE: 0.467
# epoch # 3	 SCORE: 0.472	 DEL: 1
#
# epoch # 6	 SCORE: 0.492	 DEL: 1
#
# epoch # 23	 SCORE: 0.515	 DEL: 1
#
# epoch # 95	 SCORE: 0.517	 DEL: 1
#
#
# REAL SCORE: 0.675
# REAL SCORE: 0.4625
# 0.46250000000000002
