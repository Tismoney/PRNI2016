# %%
import Subsection as ss
# %matplotlib inline

# %%
grid_cv = ss.StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
eval_cv = ss.StratifiedKFold(n_splits=10, shuffle=True, random_state=1)

# %%
Sub = ss.Subsection_up(eval_cv=eval_cv, grid_cv=grid_cv)

# %%
Sub.init_data()

# %%
Sub.init_params(
            k_tr            = 4,
            k_bag           = 2,
            collect_n       = 10,
            size_dim        = 264,
            num_iteration   = 400,
            learning_rate   = 0.4,
            max_vec         = 40,
            max_porog       = 0,
            param_grid      = dict(  classifier__C=[0.5], 
                                     classifier__penalty = ['l1'],
                                     classifier__max_iter = [50]) )

# %%
Sub.get_result()
# Out:
# INIT	 SCORE: 0.262
# epoch # 27	 SCORE: 0.355	 ADD: 126
#
# epoch # 32	 SCORE: 0.515	 ADD: 111
#
# epoch # 52	 SCORE: 0.599	 ADD: 106
#
# epoch # 60	 SCORE: 0.659	 ADD: 108
#
# epoch # 66	 SCORE: 0.669	 ADD: 123
#
# epoch # 90	 SCORE: 0.695	 ADD: 114
#
# epoch # 106	 SCORE: 0.722	 ADD: 116
#
# epoch # 178	 SCORE: 0.780	 ADD: 97
#
# epoch # 214	 SCORE: 0.787	 ADD: 113
#
# epoch # 231	 SCORE: 0.792	 ADD: 113
#
# epoch # 274	 SCORE: 0.797	 ADD: 105
#
# epoch # 354	 SCORE: 0.802	 ADD: 86
#
#
# REAL SCORE: 0.433333333333
# INIT	 SCORE: 0.445
# epoch # 82	 SCORE: 0.445	 ADD: 109
#
# epoch # 95	 SCORE: 0.489	 ADD: 97
#
# epoch # 99	 SCORE: 0.689	 ADD: 110
#
# epoch # 111	 SCORE: 0.727	 ADD: 122
#
# epoch # 119	 SCORE: 0.746	 ADD: 106
#
# epoch # 140	 SCORE: 0.766	 ADD: 84
#
# epoch # 145	 SCORE: 0.781	 ADD: 115
#
# epoch # 294	 SCORE: 0.793	 ADD: 97
#
# epoch # 397	 SCORE: 0.801	 ADD: 82
#
# epoch # 398	 SCORE: 0.833	 ADD: 80
#
#
# REAL SCORE: 0.4
# INIT	 SCORE: 0.431
# epoch # 25	 SCORE: 0.569	 ADD: 121
#
# epoch # 41	 SCORE: 0.635	 ADD: 112
#
# epoch # 57	 SCORE: 0.675	 ADD: 116
#
# epoch # 66	 SCORE: 0.693	 ADD: 123
#
# epoch # 90	 SCORE: 0.713	 ADD: 120
#
# epoch # 202	 SCORE: 0.730	 ADD: 102
#
# epoch # 214	 SCORE: 0.765	 ADD: 96
#
#
# REAL SCORE: 0.6
# INIT	 SCORE: 0.405
# epoch # 14	 SCORE: 0.452	 ADD: 96
#
# epoch # 73	 SCORE: 0.524	 ADD: 120
#
# epoch # 91	 SCORE: 0.577	 ADD: 121
#
# epoch # 101	 SCORE: 0.653	 ADD: 110
#
# epoch # 111	 SCORE: 0.687	 ADD: 105
#
# epoch # 116	 SCORE: 0.697	 ADD: 78
#
# epoch # 157	 SCORE: 0.699	 ADD: 100
#
# epoch # 161	 SCORE: 0.704	 ADD: 117
#
# epoch # 195	 SCORE: 0.733	 ADD: 98
#
# epoch # 240	 SCORE: 0.734	 ADD: 119
#
# epoch # 256	 SCORE: 0.749	 ADD: 89
#
# epoch # 279	 SCORE: 0.750	 ADD: 82
#
# epoch # 315	 SCORE: 0.760	 ADD: 95
#
# epoch # 326	 SCORE: 0.768	 ADD: 98
#
# epoch # 372	 SCORE: 0.771	 ADD: 107
#
#
# REAL SCORE: 0.625
# INIT	 SCORE: 0.297
# epoch # 32	 SCORE: 0.599	 ADD: 98
#
# epoch # 41	 SCORE: 0.612	 ADD: 125
#
# epoch # 42	 SCORE: 0.708	 ADD: 111
#
# epoch # 110	 SCORE: 0.718	 ADD: 111
#
# epoch # 122	 SCORE: 0.740	 ADD: 114
#
# epoch # 154	 SCORE: 0.747	 ADD: 117
#
# epoch # 212	 SCORE: 0.758	 ADD: 111
#
# epoch # 276	 SCORE: 0.771	 ADD: 98
#
#
# REAL SCORE: 0.525
# INIT	 SCORE: 0.382
# epoch # 32	 SCORE: 0.398	 ADD: 120
#
# epoch # 35	 SCORE: 0.432	 ADD: 118
#
# epoch # 36	 SCORE: 0.503	 ADD: 121
#
# epoch # 51	 SCORE: 0.545	 ADD: 116
#
# epoch # 60	 SCORE: 0.553	 ADD: 118
#
# epoch # 64	 SCORE: 0.593	 ADD: 122
#
# epoch # 68	 SCORE: 0.800	 ADD: 99
#
# epoch # 76	 SCORE: 0.809	 ADD: 101
#
# epoch # 120	 SCORE: 0.845	 ADD: 109
#
# epoch # 133	 SCORE: 0.847	 ADD: 97
#
# epoch # 152	 SCORE: 0.853	 ADD: 100
#
# epoch # 158	 SCORE: 0.866	 ADD: 115
#
# epoch # 169	 SCORE: 0.880	 ADD: 109
#
# epoch # 207	 SCORE: 0.885	 ADD: 114
#
#
# REAL SCORE: 0.525
# INIT	 SCORE: 0.425
# epoch # 63	 SCORE: 0.594	 ADD: 111
#
# epoch # 70	 SCORE: 0.612	 ADD: 120
#
# epoch # 86	 SCORE: 0.617	 ADD: 96
#
# epoch # 244	 SCORE: 0.628	 ADD: 99
#
# epoch # 258	 SCORE: 0.684	 ADD: 105
#
# epoch # 320	 SCORE: 0.690	 ADD: 105
#
# epoch # 370	 SCORE: 0.701	 ADD: 81
#
# epoch # 397	 SCORE: 0.702	 ADD: 119
#
#
# REAL SCORE: 0.475
# INIT	 SCORE: 0.589
# epoch # 48	 SCORE: 0.650	 ADD: 98
#
# epoch # 74	 SCORE: 0.656	 ADD: 112
#
# epoch # 106	 SCORE: 0.675	 ADD: 99
#
# epoch # 125	 SCORE: 0.753	 ADD: 97
#
# epoch # 155	 SCORE: 0.789	 ADD: 93
#
# epoch # 281	 SCORE: 0.794	 ADD: 0
#
# epoch # 340	 SCORE: 0.801	 ADD: 90
#
#
# REAL SCORE: 0.45
# INIT	 SCORE: 0.495
# epoch # 42	 SCORE: 0.543	 ADD: 126
#
# epoch # 67	 SCORE: 0.565	 ADD: 121
#
# epoch # 73	 SCORE: 0.620	 ADD: 125
#
# epoch # 80	 SCORE: 0.656	 ADD: 122
#
# epoch # 93	 SCORE: 0.724	 ADD: 112
#
# epoch # 137	 SCORE: 0.727	 ADD: 94
#
# epoch # 138	 SCORE: 0.820	 ADD: 115
#
# epoch # 273	 SCORE: 0.847	 ADD: 54
#
# epoch # 388	 SCORE: 0.858	 ADD: 91
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.421
# epoch # 38	 SCORE: 0.575	 ADD: 107
#
# epoch # 46	 SCORE: 0.632	 ADD: 127
#
# epoch # 98	 SCORE: 0.642	 ADD: 121
#
# epoch # 106	 SCORE: 0.668	 ADD: 111
#
# epoch # 144	 SCORE: 0.698	 ADD: 76
#
# epoch # 156	 SCORE: 0.715	 ADD: 118
#
# epoch # 177	 SCORE: 0.736	 ADD: 101
#
# epoch # 180	 SCORE: 0.764	 ADD: 83
#
# epoch # 252	 SCORE: 0.765	 ADD: 96
#
# epoch # 285	 SCORE: 0.793	 ADD: 78
#
# epoch # 319	 SCORE: 0.799	 ADD: 115
#
# epoch # 335	 SCORE: 0.801	 ADD: 90
#
# epoch # 397	 SCORE: 0.804	 ADD: 103
#
#
# REAL SCORE: 0.325
# REAL SCORE: 0.500833333333
# 0.50083333333333335
