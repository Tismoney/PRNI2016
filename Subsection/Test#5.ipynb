# %%
import Subsection as ss
# %matplotlib inline

# %%
grid_cv = ss.StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
eval_cv = ss.StratifiedKFold(n_splits=10, shuffle=True, random_state=1)

# %%
Sub = ss.Subsection_up(eval_cv=eval_cv, grid_cv=grid_cv)

# %%
Sub.init_data()

# %%
Sub.init_params(
            k_tr            = 4,
            k_bag           = 2,
            collect_n       = 10,
            size_dim        = 264,
            num_iteration   = 100,
            learning_rate   = 0.4,
            max_vec         = 12,
            max_porog       = 0)

# %%
Sub.get_result()
# Out:
# INIT	 SCORE: 0.440
#
# REAL SCORE: 0.416666666667
# INIT	 SCORE: 0.408
# epoch # 73	 SCORE: 0.650	 ADD: 112
#
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.457
# epoch # 68	 SCORE: 0.795	 ADD: 112
#
#
# REAL SCORE: 0.6
# INIT	 SCORE: 0.526
#
# REAL SCORE: 0.3
# INIT	 SCORE: 0.392
# epoch # 64	 SCORE: 0.570	 ADD: 120
#
#
# REAL SCORE: 0.55
# INIT	 SCORE: 0.519
# epoch # 43	 SCORE: 0.650	 ADD: 85
#
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.478
# epoch # 59	 SCORE: 0.490	 ADD: 126
#
# epoch # 86	 SCORE: 0.519	 ADD: 118
#
#
# REAL SCORE: 0.325
# INIT	 SCORE: 0.283
# epoch # 93	 SCORE: 0.406	 ADD: 127
#
#
# REAL SCORE: 0.625
# INIT	 SCORE: 0.336
#
# REAL SCORE: 0.325
# INIT	 SCORE: 0.490
#
# REAL SCORE: 0.5
# REAL SCORE: 0.464166666667
# 0.46416666666666667

# %%
Sub.init_params(
            k_tr            = 1,
            k_bag           = 1,
            collect_n       = 10,
            size_dim        = 264,
            num_iteration   = 250,
            learning_rate   = 0.5,
            max_vec         = 16,
            max_porog       = 0)

# %%
Sub.get_result()
# Out:
# INIT	 SCORE: 0.501
# epoch # 56	 SCORE: 0.525	 ADD: 250
#
# epoch # 106	 SCORE: 0.663	 ADD: 202
#
# epoch # 146	 SCORE: 0.703	 ADD: 237
#
# epoch # 169	 SCORE: 0.733	 ADD: 241
#
# epoch # 221	 SCORE: 0.737	 ADD: 228
#
# epoch # 239	 SCORE: 0.744	 ADD: 228
#
# epoch # 242	 SCORE: 0.759	 ADD: 241
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.413
# epoch # 86	 SCORE: 0.588	 ADD: 254
#
# epoch # 91	 SCORE: 0.670	 ADD: 250
#
# epoch # 104	 SCORE: 0.731	 ADD: 221
#
# epoch # 130	 SCORE: 0.854	 ADD: 256
#
# epoch # 176	 SCORE: 0.876	 ADD: 240
#
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.395
# epoch # 120	 SCORE: 0.676	 ADD: 251
#
# epoch # 156	 SCORE: 0.725	 ADD: 258
#
# epoch # 211	 SCORE: 0.736	 ADD: 257
#
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.603
# epoch # 39	 SCORE: 0.712	 ADD: 221
#
# epoch # 81	 SCORE: 0.715	 ADD: 237
#
# epoch # 217	 SCORE: 0.720	 ADD: 213
#
#
# REAL SCORE: 0.425
# INIT	 SCORE: 0.438
# epoch # 158	 SCORE: 0.475	 ADD: 258
#
# epoch # 160	 SCORE: 0.646	 ADD: 231
#
# epoch # 214	 SCORE: 0.664	 ADD: 221
#
# epoch # 229	 SCORE: 0.733	 ADD: 142
#
# epoch # 243	 SCORE: 0.738	 ADD: 255
#
#
# REAL SCORE: 0.55
# INIT	 SCORE: 0.370
# epoch # 81	 SCORE: 0.595	 ADD: 237
#
# epoch # 182	 SCORE: 0.616	 ADD: 224
#
# epoch # 223	 SCORE: 0.640	 ADD: 257
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.518
# epoch # 63	 SCORE: 0.599	 ADD: 253
#
# epoch # 184	 SCORE: 0.624	 ADD: 246
#
#
# REAL SCORE: 0.55
# INIT	 SCORE: 0.449
# epoch # 62	 SCORE: 0.597	 ADD: 221
#
# epoch # 130	 SCORE: 0.669	 ADD: 232
#
# epoch # 144	 SCORE: 0.728	 ADD: 226
#
# epoch # 214	 SCORE: 0.733	 ADD: 242
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.341
# epoch # 131	 SCORE: 0.611	 ADD: 160
#
# epoch # 185	 SCORE: 0.626	 ADD: 255
#
# epoch # 190	 SCORE: 0.686	 ADD: 230
#
# epoch # 233	 SCORE: 0.690	 ADD: 255
#
#
# REAL SCORE: 0.325
# INIT	 SCORE: 0.373
# epoch # 97	 SCORE: 0.484	 ADD: 241
#
# epoch # 132	 SCORE: 0.538	 ADD: 249
#
# epoch # 171	 SCORE: 0.564	 ADD: 256
#
# epoch # 211	 SCORE: 0.599	 ADD: 226
#
# epoch # 212	 SCORE: 0.605	 ADD: 244
#
# epoch # 216	 SCORE: 0.685	 ADD: 220
#
# epoch # 241	 SCORE: 0.688	 ADD: 220
#
#
# REAL SCORE: 0.525
# REAL SCORE: 0.5325
# 0.53250000000000008

# %%
Sub.init_params(
            k_tr            = 1,
            k_bag           = 1,
            collect_n       = 10,
            size_dim        = 264,
            num_iteration   = 700,
            learning_rate   = 0.2,
            max_vec         = 4,
            max_porog       = 0)

# %%
Sub.get_result()
# Out:
# INIT	 SCORE: 0.501
# epoch # 123	 SCORE: 0.658	 ADD: 259
#
# epoch # 303	 SCORE: 0.680	 ADD: 258
#
# epoch # 483	 SCORE: 0.754	 ADD: 231
#
# REAL SCORE: 0.633333333333
# INIT	 SCORE: 0.413
#
# epoch # 196	 SCORE: 0.588	 ADD: 254
#
# epoch # 412	 SCORE: 0.598	 ADD: 251
#
# epoch # 415	 SCORE: 0.740	 ADD: 257
#
# REAL SCORE: 0.3
# INIT	 SCORE: 0.395
# epoch # 314	 SCORE: 0.604	 ADD: 250
#
# epoch # 516	 SCORE: 0.697	 ADD: 258
#
# epoch # 568	 SCORE: 0.703	 ADD: 257
#
# REAL SCORE: 0.6
# INIT	 SCORE: 0.603
# epoch # 202	 SCORE: 0.735	 ADD: 258
#
# epoch # 596	 SCORE: 0.762	 ADD: 260
#
# REAL SCORE: 0.3
# INIT	 SCORE: 0.443
# epoch # 257	 SCORE: 0.583	 ADD: 253
#
# epoch # 462	 SCORE: 0.612	 ADD: 257
#
# epoch # 649	 SCORE: 0.620	 ADD: 229
#
# REAL SCORE: 0.325
# INIT	 SCORE: 0.365
#
# epoch # 475	 SCORE: 0.731	 ADD: 231
#
# epoch # 532	 SCORE: 0.756	 ADD: 255
#
# REAL SCORE: 0.425
# INIT	 SCORE: 0.518
# epoch # 280	 SCORE: 0.663	 ADD: 246
#
# epoch # 384	 SCORE: 0.668	 ADD: 249
#
# epoch # 599	 SCORE: 0.672	 ADD: 256
#
# REAL SCORE: 0.425
# INIT	 SCORE: 0.449
#
# epoch # 268	 SCORE: 0.463	 ADD: 261
#
# epoch # 427	 SCORE: 0.569	 ADD: 259
#
# epoch # 457	 SCORE: 0.614	 ADD: 246
#
# REAL SCORE: 0.625
# INIT	 SCORE: 0.341
# epoch # 372	 SCORE: 0.414	 ADD: 247
#
# epoch # 451	 SCORE: 0.638	 ADD: 231
#
# epoch # 456	 SCORE: 0.647	 ADD: 257
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.373
# epoch # 322	 SCORE: 0.483	 ADD: 261
#
# epoch # 323	 SCORE: 0.603	 ADD: 258
#
# epoch # 399	 SCORE: 0.643	 ADD: 258
#
# REAL SCORE: 0.325
# REAL SCORE: 0.460833333333
# 0.46083333333333332

# %%
Sub.init_params(
            k_tr            = 1,
            k_bag           = 1,
            collect_n       = 10,
            size_dim        = 264,
            num_iteration   = 1000,
            learning_rate   = 0.2,
            max_vec         = 4,
            max_porog       = 0)

# %%
Sub.get_result()
# Out:
# INIT	 SCORE: 0.501
# epoch # 339	 SCORE: 0.658	 ADD: 259
#
# epoch # 702	 SCORE: 0.751	 ADD: 223
#
# epoch # 890	 SCORE: 0.767	 ADD: 245
#
# REAL SCORE: 0.833333333333
# INIT	 SCORE: 0.413
#
# epoch # 370	 SCORE: 0.691	 ADD: 246
#
# epoch # 561	 SCORE: 0.717	 ADD: 241
#
# epoch # 802	 SCORE: 0.728	 ADD: 254
#
# REAL SCORE: 0.8
# INIT	 SCORE: 0.395
# epoch # 283	 SCORE: 0.676	 ADD: 251
#
# epoch # 709	 SCORE: 0.694	 ADD: 229
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.603
# epoch # 248	 SCORE: 0.644	 ADD: 261
#
# epoch # 391	 SCORE: 0.762	 ADD: 258
#
# epoch # 958	 SCORE: 0.798	 ADD: 202
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.443
#
# epoch # 307	 SCORE: 0.646	 ADD: 259
#
# epoch # 762	 SCORE: 0.733	 ADD: 246
#
# REAL SCORE: 0.55
# INIT	 SCORE: 0.370
# epoch # 287	 SCORE: 0.589	 ADD: 252
#
# epoch # 679	 SCORE: 0.589	 ADD: 246
#
# epoch # 870	 SCORE: 0.676	 ADD: 232
#
# REAL SCORE: 0.45
# INIT	 SCORE: 0.518
#
# epoch # 299	 SCORE: 0.663	 ADD: 246
#
# epoch # 594	 SCORE: 0.668	 ADD: 249
#
# epoch # 931	 SCORE: 0.721	 ADD: 233
#
# REAL SCORE: 0.3
# INIT	 SCORE: 0.449
# epoch # 336	 SCORE: 0.480	 ADD: 243
#
# epoch # 653	 SCORE: 0.634	 ADD: 258
#
# REAL SCORE: 0.425
# INIT	 SCORE: 0.341
# epoch # 421	 SCORE: 0.636	 ADD: 241
#
# epoch # 827	 SCORE: 0.641	 ADD: 236
#
# epoch # 941	 SCORE: 0.651	 ADD: 255
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.373
#
# epoch # 366	 SCORE: 0.635	 ADD: 259
#
# epoch # 692	 SCORE: 0.731	 ADD: 231
#
# REAL SCORE: 0.425
# REAL SCORE: 0.528333333333
# 0.52833333333333332

# %%
Sub.init_params(
            k_tr            = 2,
            k_bag           = 2,
            collect_n       = 10,
            size_dim        = 264,
            num_iteration   = 800,
            learning_rate   = 0.2,
            max_vec         = 8,
            max_porog       = 0)

# %%
Sub.get_result()
# Out:
# INIT	 SCORE: 0.528
# epoch # 329	 SCORE: 0.600	 ADD: 103
#
# epoch # 444	 SCORE: 0.622	 ADD: 127
#
# epoch # 631	 SCORE: 0.630	 ADD: 119
#
# REAL SCORE: 0.6
# INIT	 SCORE: 0.378
#
# epoch # 194	 SCORE: 0.515	 ADD: 128
#
# epoch # 369	 SCORE: 0.628	 ADD: 124
#
# epoch # 544	 SCORE: 0.753	 ADD: 120
#
# REAL SCORE: 0.6
# INIT	 SCORE: 0.447
# epoch # 192	 SCORE: 0.603	 ADD: 127
#
# epoch # 373	 SCORE: 0.797	 ADD: 121
#
# epoch # 480	 SCORE: 0.832	 ADD: 116
#
# REAL SCORE: 0.6
# INIT	 SCORE: 0.601
# epoch # 187	 SCORE: 0.649	 ADD: 121
#
# epoch # 274	 SCORE: 0.682	 ADD: 127
#
# epoch # 671	 SCORE: 0.725	 ADD: 111
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.516
# epoch # 148	 SCORE: 0.755	 ADD: 112
#
# epoch # 450	 SCORE: 0.766	 ADD: 116
#
# REAL SCORE: 0.625
# INIT	 SCORE: 0.543
# epoch # 205	 SCORE: 0.682	 ADD: 112
#
# epoch # 506	 SCORE: 0.699	 ADD: 105
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.653
# epoch # 172	 SCORE: 0.659	 ADD: 115
#
# epoch # 449	 SCORE: 0.685	 ADD: 111
#
# epoch # 588	 SCORE: 0.697	 ADD: 127
#
# REAL SCORE: 0.425
# INIT	 SCORE: 0.427
#
# epoch # 267	 SCORE: 0.571	 ADD: 121
#
# epoch # 355	 SCORE: 0.699	 ADD: 117
#
# epoch # 558	 SCORE: 0.700	 ADD: 119
#
# REAL SCORE: 0.575
# INIT	 SCORE: 0.455
# epoch # 149	 SCORE: 0.550	 ADD: 105
#
# epoch # 354	 SCORE: 0.617	 ADD: 125
#
# epoch # 543	 SCORE: 0.772	 ADD: 111
#
# REAL SCORE: 0.625
# INIT	 SCORE: 0.481
# epoch # 122	 SCORE: 0.688	 ADD: 128
#
# epoch # 326	 SCORE: 0.755	 ADD: 112
#
# epoch # 441	 SCORE: 0.798	 ADD: 113
#
# REAL SCORE: 0.525
# REAL SCORE: 0.5875
# 0.58750000000000002
