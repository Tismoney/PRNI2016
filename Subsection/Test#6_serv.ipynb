# %%
import Subsection as ss
# %matplotlib inline

# %%
grid_cv = ss.StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
eval_cv = ss.StratifiedKFold(n_splits=10, shuffle=True, random_state=1)

# %% [markdown]
# ## Up

# %%
Sub = ss.Subsection_up(eval_cv=eval_cv, grid_cv=grid_cv)
Sub.init_data()

# %%
Sub.init_params(
            k_tr            = 3,
            k_bag           = 3,
            collect_n       = 20,
            size_dim        = 264,
            num_iteration   = 800,
            learning_rate   = 0.2,
            max_vec         = -1,
            max_porog       = 0)

Sub.get_result()
# Out:
# INIT	 SCORE: 0.568
# epoch # 121	 SCORE: 0.580	 ADD: 79
#
# epoch # 285	 SCORE: 0.584	 ADD: 80
#
# epoch # 636	 SCORE: 0.608	 ADD: 65
#
# epoch # 728	 SCORE: 0.630	 ADD: 81
#
#
# REAL SCORE: 0.35
# INIT	 SCORE: 0.350
# epoch # 149	 SCORE: 0.489	 ADD: 85
#
# epoch # 265	 SCORE: 0.547	 ADD: 74
#
# epoch # 504	 SCORE: 0.566	 ADD: 77
#
# epoch # 646	 SCORE: 0.571	 ADD: 76
#
#
# REAL SCORE: 0.8
# INIT	 SCORE: 0.475
# epoch # 121	 SCORE: 0.689	 ADD: 77
#
# epoch # 216	 SCORE: 0.695	 ADD: 77
#
# epoch # 480	 SCORE: 0.698	 ADD: 77
#
# epoch # 581	 SCORE: 0.710	 ADD: 76
#
#
# REAL SCORE: 0.8
# INIT	 SCORE: 0.539
# epoch # 112	 SCORE: 0.548	 ADD: 85
#
# epoch # 234	 SCORE: 0.620	 ADD: 83
#
# epoch # 515	 SCORE: 0.639	 ADD: 76
#
# epoch # 621	 SCORE: 0.645	 ADD: 80
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.481
# epoch # 139	 SCORE: 0.639	 ADD: 76
#
# epoch # 634	 SCORE: 0.641	 ADD: 72
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.510
# epoch # 153	 SCORE: 0.583	 ADD: 77
#
# epoch # 238	 SCORE: 0.613	 ADD: 83
#
# epoch # 341	 SCORE: 0.667	 ADD: 78
#
# epoch # 476	 SCORE: 0.741	 ADD: 74
#
# epoch # 566	 SCORE: 0.775	 ADD: 81
#
# epoch # 655	 SCORE: 0.778	 ADD: 78
#
#
# REAL SCORE: 0.325
# INIT	 SCORE: 0.553
# epoch # 160	 SCORE: 0.706	 ADD: 74
#
# epoch # 232	 SCORE: 0.725	 ADD: 84
#
# epoch # 324	 SCORE: 0.737	 ADD: 77
#
# epoch # 660	 SCORE: 0.742	 ADD: 76
#
#
# REAL SCORE: 0.525
# INIT	 SCORE: 0.607
# epoch # 124	 SCORE: 0.678	 ADD: 80
#
# epoch # 618	 SCORE: 0.685	 ADD: 60
#
#
# REAL SCORE: 0.4
# INIT	 SCORE: 0.468
# epoch # 110	 SCORE: 0.665	 ADD: 80
#
# epoch # 223	 SCORE: 0.717	 ADD: 78
#
# epoch # 383	 SCORE: 0.720	 ADD: 80
#
#
# REAL SCORE: 0.3
# INIT	 SCORE: 0.513
# epoch # 126	 SCORE: 0.654	 ADD: 75
#
# epoch # 444	 SCORE: 0.719	 ADD: 46
#
# epoch # 582	 SCORE: 0.721	 ADD: 74
#
# epoch # 695	 SCORE: 0.794	 ADD: 75
#
#
# REAL SCORE: 0.65
# REAL SCORE: 0.545
# 0.54500000000000004

# %%
Sub.init_params(
            k_tr            = 3,
            k_bag           = 3,
            collect_n       = 20,
            size_dim        = 264,
            num_iteration   = 800,
            learning_rate   = 0.2,
            max_vec         = 12,
            max_porog       = 0)

Sub.get_result()
# Out:
# INIT	 SCORE: 0.568
# epoch # 213	 SCORE: 0.588	 ADD: 80
#
# epoch # 383	 SCORE: 0.605	 ADD: 79
#
# epoch # 757	 SCORE: 0.637	 ADD: 63
#
# REAL SCORE: 0.366666666667
# INIT	 SCORE: 0.350
#
# epoch # 97	 SCORE: 0.464	 ADD: 84
#
# epoch # 254	 SCORE: 0.552	 ADD: 74
#
# epoch # 351	 SCORE: 0.570	 ADD: 81
#
# REAL SCORE: 0.8
# INIT	 SCORE: 0.480
# epoch # 106	 SCORE: 0.689	 ADD: 77
#
# epoch # 343	 SCORE: 0.695	 ADD: 77
#
# epoch # 533	 SCORE: 0.698	 ADD: 77
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.539
# epoch # 101	 SCORE: 0.609	 ADD: 84
#
# epoch # 188	 SCORE: 0.652	 ADD: 76
#
# epoch # 307	 SCORE: 0.662	 ADD: 80
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.481
# epoch # 162	 SCORE: 0.639	 ADD: 76
#
# epoch # 641	 SCORE: 0.641	 ADD: 72
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.510
# epoch # 97	 SCORE: 0.606	 ADD: 79
#
# epoch # 183	 SCORE: 0.681	 ADD: 78
#
# epoch # 278	 SCORE: 0.707	 ADD: 83
#
# REAL SCORE: 0.325
# INIT	 SCORE: 0.553
#
# epoch # 129	 SCORE: 0.570	 ADD: 78
#
# epoch # 269	 SCORE: 0.652	 ADD: 84
#
# epoch # 387	 SCORE: 0.735	 ADD: 75
#
# REAL SCORE: 0.525
# INIT	 SCORE: 0.607
# epoch # 168	 SCORE: 0.683	 ADD: 80
#
# epoch # 406	 SCORE: 0.706	 ADD: 61
#
# REAL SCORE: 0.425
# INIT	 SCORE: 0.468
# epoch # 185	 SCORE: 0.684	 ADD: 78
#
# epoch # 274	 SCORE: 0.729	 ADD: 78
#
# epoch # 653	 SCORE: 0.752	 ADD: 58
#
# REAL SCORE: 0.3
# INIT	 SCORE: 0.513
#
# epoch # 190	 SCORE: 0.654	 ADD: 75
#
# epoch # 405	 SCORE: 0.687	 ADD: 54
#
# epoch # 689	 SCORE: 0.722	 ADD: 63
#
# REAL SCORE: 0.625
# REAL SCORE: 0.516666666667
# 0.51666666666666661

# %%
Sub.init_params(
            k_tr            = 4,
            k_bag           = 5,
            collect_n       = 20,
            size_dim        = 264,
            num_iteration   = 500,
            learning_rate   = 0.2,
            max_vec         = -1,
            max_porog       = 0)

Sub.get_result()
# Out:
# INIT	 SCORE: 0.550
# epoch # 34	 SCORE: 0.708	 ADD: 50
#
# epoch # 91	 SCORE: 0.772	 ADD: 42
#
# epoch # 210	 SCORE: 0.831	 ADD: 40
#
# REAL SCORE: 0.45
# INIT	 SCORE: 0.400
# epoch # 78	 SCORE: 0.664	 ADD: 50
#
# epoch # 248	 SCORE: 0.719	 ADD: 34
#
#
# REAL SCORE: 0.4
# INIT	 SCORE: 0.502
# epoch # 68	 SCORE: 0.593	 ADD: 49
#
# epoch # 137	 SCORE: 0.624	 ADD: 49
#
# epoch # 350	 SCORE: 0.627	 ADD: 41
#
#
# REAL SCORE: 0.6
# INIT	 SCORE: 0.461
# epoch # 42	 SCORE: 0.593	 ADD: 50
#
# epoch # 166	 SCORE: 0.608	 ADD: 39
#
# epoch # 267	 SCORE: 0.630	 ADD: 48
#
#
# REAL SCORE: 0.875
# INIT	 SCORE: 0.444
# epoch # 44	 SCORE: 0.521	 ADD: 50
#
# epoch # 130	 SCORE: 0.578	 ADD: 41
#
# epoch # 203	 SCORE: 0.598	 ADD: 43
#
# epoch # 380	 SCORE: 0.605	 ADD: 42
#
#
# REAL SCORE: 0.625
# INIT	 SCORE: 0.447
# epoch # 82	 SCORE: 0.568	 ADD: 49
#
# epoch # 174	 SCORE: 0.583	 ADD: 40
#
# epoch # 288	 SCORE: 0.585	 ADD: 47
#
#
# REAL SCORE: 0.625
# INIT	 SCORE: 0.492
# epoch # 46	 SCORE: 0.644	 ADD: 50
#
# epoch # 99	 SCORE: 0.664	 ADD: 49
#
# epoch # 234	 SCORE: 0.722	 ADD: 40
#
#
# REAL SCORE: 0.625
# INIT	 SCORE: 0.543
# epoch # 94	 SCORE: 0.557	 ADD: 50
#
# epoch # 150	 SCORE: 0.562	 ADD: 49
#
# epoch # 319	 SCORE: 0.647	 ADD: 39
#
#
# REAL SCORE: 0.425
# INIT	 SCORE: 0.455
# epoch # 98	 SCORE: 0.593	 ADD: 47
#
# epoch # 224	 SCORE: 0.687	 ADD: 39
#
# epoch # 356	 SCORE: 0.699	 ADD: 43
#
#
# REAL SCORE: 0.525
# INIT	 SCORE: 0.443
# epoch # 59	 SCORE: 0.710	 ADD: 50
#
# epoch # 133	 SCORE: 0.725	 ADD: 45
#
# epoch # 247	 SCORE: 0.729	 ADD: 38
#
# epoch # 335	 SCORE: 0.734	 ADD: 45
#
#
# REAL SCORE: 0.525
# REAL SCORE: 0.5675
# 0.56750000000000012

# %%
Sub.init_params(
            k_tr            = 1,
            k_bag           = 1,
            collect_n       = 20,
            size_dim        = 264,
            num_iteration   = 1500,
            learning_rate   = 0.2,
            max_vec         = 8,
            max_porog       = 0)

Sub.get_result()
# Out:
# INIT	 SCORE: 0.391
# epoch # 228	 SCORE: 0.711	 ADD: 247
#
# epoch # 580	 SCORE: 0.743	 ADD: 260
#
# epoch # 814	 SCORE: 0.748	 ADD: 255
#
#
# REAL SCORE: 0.333333333333
# INIT	 SCORE: 0.366
# epoch # 287	 SCORE: 0.582	 ADD: 261
#
# epoch # 578	 SCORE: 0.630	 ADD: 232
#
# epoch # 910	 SCORE: 0.657	 ADD: 246
#
# epoch # 1323	 SCORE: 0.703	 ADD: 244
#
#
# REAL SCORE: 0.4
# INIT	 SCORE: 0.614
# epoch # 419	 SCORE: 0.665	 ADD: 247
#
# epoch # 1165	 SCORE: 0.694	 ADD: 204
#
#
# REAL SCORE: 0.7
# INIT	 SCORE: 0.415
# epoch # 332	 SCORE: 0.452	 ADD: 261
#
# epoch # 608	 SCORE: 0.631	 ADD: 229
#
#
# REAL SCORE: 0.775
# INIT	 SCORE: 0.291
# epoch # 286	 SCORE: 0.590	 ADD: 245
#
# epoch # 609	 SCORE: 0.641	 ADD: 259
#
# epoch # 953	 SCORE: 0.644	 ADD: 254
#
# epoch # 1277	 SCORE: 0.723	 ADD: 246
#
#
# REAL SCORE: 0.55
# INIT	 SCORE: 0.351
# epoch # 349	 SCORE: 0.372	 ADD: 260
#
# epoch # 888	 SCORE: 0.573	 ADD: 245
#
# epoch # 1264	 SCORE: 0.604	 ADD: 244
#
# epoch # 1467	 SCORE: 0.644	 ADD: 232
#
#
# REAL SCORE: 0.4
# INIT	 SCORE: 0.559
# epoch # 328	 SCORE: 0.563	 ADD: 234
#
# epoch # 605	 SCORE: 0.675	 ADD: 260
#
# epoch # 981	 SCORE: 0.688	 ADD: 232
#
# epoch # 1125	 SCORE: 0.742	 ADD: 238
#
# epoch # 1440	 SCORE: 0.773	 ADD: 244
#
#
# REAL SCORE: 0.625
# INIT	 SCORE: 0.568
# epoch # 215	 SCORE: 0.715	 ADD: 252
#
# epoch # 538	 SCORE: 0.719	 ADD: 256
#
# epoch # 852	 SCORE: 0.720	 ADD: 214
#
# epoch # 1189	 SCORE: 0.746	 ADD: 244
#
#
# REAL SCORE: 0.3
# INIT	 SCORE: 0.287
# epoch # 332	 SCORE: 0.544	 ADD: 261
#
# epoch # 624	 SCORE: 0.545	 ADD: 248
#
# epoch # 862	 SCORE: 0.630	 ADD: 232
#
# epoch # 1228	 SCORE: 0.697	 ADD: 244
#
#
# REAL SCORE: 0.775
# INIT	 SCORE: 0.542
# epoch # 240	 SCORE: 0.568	 ADD: 251
#
# epoch # 496	 SCORE: 0.570	 ADD: 255
#
# epoch # 821	 SCORE: 0.587	 ADD: 257
#
# epoch # 1176	 SCORE: 0.614	 ADD: 234
#
# epoch # 1464	 SCORE: 0.654	 ADD: 254
#
#
# REAL SCORE: 0.225
# REAL SCORE: 0.508333333333
# 0.50833333333333341

# %% [markdown]
# ## Low

# %%
Low = ss.Subsection_low(eval_cv=eval_cv, grid_cv=grid_cv)
Low.init_data()

# %%
Low.init_params(
            k_init          = 160,
            k_split         = 5,
            collect_n       = 20,
            size_dim        = 264,
            num_iteration   = 500,
            learning_rate   = 0.5,
            min_vec         = 40,
            max_porog       = 0)

Low.get_result()
# Out:
# INIT	 SCORE: 0.618
# epoch # 17	 SCORE: 0.630	 DEL: 6
#
# epoch # 74	 SCORE: 0.635	 DEL: 0
#
# epoch # 190	 SCORE: 0.642	 DEL: 4
#
#
# REAL SCORE: 0.733333333333
# INIT	 SCORE: 0.399
# epoch # 8	 SCORE: 0.416	 DEL: 2
#
# epoch # 12	 SCORE: 0.425	 DEL: 2
#
# epoch # 64	 SCORE: 0.428	 DEL: 1
#
# epoch # 71	 SCORE: 0.434	 DEL: 0
#
# epoch # 96	 SCORE: 0.444	 DEL: 1
#
# epoch # 117	 SCORE: 0.475	 DEL: 0
#
# epoch # 121	 SCORE: 0.489	 DEL: 0
#
# epoch # 214	 SCORE: 0.498	 DEL: 5
#
#
# REAL SCORE: 0.7
# INIT	 SCORE: 0.711
# epoch # 35	 SCORE: 0.718	 DEL: 2
#
# epoch # 58	 SCORE: 0.729	 DEL: 1
#
# epoch # 105	 SCORE: 0.738	 DEL: 0
#
# epoch # 157	 SCORE: 0.740	 DEL: 1
#
# epoch # 183	 SCORE: 0.744	 DEL: 4
#
# epoch # 219	 SCORE: 0.749	 DEL: 2
#
#
# REAL SCORE: 0.6
# INIT	 SCORE: 0.484
# epoch # 15	 SCORE: 0.502	 DEL: 2
#
# epoch # 44	 SCORE: 0.505	 DEL: 0
#
# epoch # 55	 SCORE: 0.534	 DEL: 0
#
# epoch # 63	 SCORE: 0.538	 DEL: 12
#
# epoch # 70	 SCORE: 0.543	 DEL: 1
#
# epoch # 79	 SCORE: 0.570	 DEL: 0
#
# epoch # 103	 SCORE: 0.582	 DEL: 7
#
#
# REAL SCORE: 0.675
# INIT	 SCORE: 0.515
# epoch # 1	 SCORE: 0.541	 DEL: 3
#
# epoch # 7	 SCORE: 0.545	 DEL: 0
#
# epoch # 26	 SCORE: 0.551	 DEL: 0
#
# epoch # 41	 SCORE: 0.551	 DEL: 2
#
# epoch # 132	 SCORE: 0.556	 DEL: 1
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.725
# epoch # 3	 SCORE: 0.755	 DEL: 0
#
# epoch # 5	 SCORE: 0.760	 DEL: 2
#
# epoch # 11	 SCORE: 0.762	 DEL: 0
#
# epoch # 47	 SCORE: 0.767	 DEL: 1
#
# epoch # 135	 SCORE: 0.772	 DEL: 0
#
# epoch # 313	 SCORE: 0.777	 DEL: 5
#
#
# REAL SCORE: 0.55
# INIT	 SCORE: 0.572
# epoch # 9	 SCORE: 0.605	 DEL: 1
#
# epoch # 58	 SCORE: 0.612	 DEL: 0
#
# epoch # 184	 SCORE: 0.643	 DEL: 0
#
#
# REAL SCORE: 0.425
# INIT	 SCORE: 0.650
# epoch # 3	 SCORE: 0.686	 DEL: 0
#
# epoch # 150	 SCORE: 0.693	 DEL: 1
#
# epoch # 237	 SCORE: 0.697	 DEL: 0
#
# epoch # 336	 SCORE: 0.707	 DEL: 0
#
# epoch # 395	 SCORE: 0.717	 DEL: 0
#
#
# REAL SCORE: 0.55
# INIT	 SCORE: 0.598
# epoch # 8	 SCORE: 0.609	 DEL: 5
#
# epoch # 32	 SCORE: 0.614	 DEL: 0
#
# epoch # 60	 SCORE: 0.618	 DEL: 5
#
# epoch # 180	 SCORE: 0.624	 DEL: 4
#
#
# REAL SCORE: 0.525
# INIT	 SCORE: 0.485
# epoch # 22	 SCORE: 0.486	 DEL: 0
#
# epoch # 30	 SCORE: 0.490	 DEL: 1
#
# epoch # 41	 SCORE: 0.492	 DEL: 0
#
# epoch # 50	 SCORE: 0.498	 DEL: 0
#
# epoch # 58	 SCORE: 0.502	 DEL: 0
#
# epoch # 88	 SCORE: 0.508	 DEL: 9
#
# epoch # 106	 SCORE: 0.518	 DEL: 0
#
#
# REAL SCORE: 0.8
# REAL SCORE: 0.620833333333
# 0.62083333333333346

# %%
Low.init_params(
            k_init          = 60,
            k_split         = 2,
            collect_n       = 20,
            size_dim        = 264,
            num_iteration   = 500,
            learning_rate   = 1,
            min_vec         = 20,
            max_porog       = 0)

Low.get_result()
# Out:
# INIT	 SCORE: 0.410
# epoch # 1	 SCORE: 0.433	 DEL: 0
#
# epoch # 3	 SCORE: 0.441	 DEL: 0
#
# epoch # 9	 SCORE: 0.459	 DEL: 1
#
# epoch # 11	 SCORE: 0.464	 DEL: 14
#
# epoch # 15	 SCORE: 0.468	 DEL: 3
#
# epoch # 18	 SCORE: 0.470	 DEL: 5
#
# epoch # 21	 SCORE: 0.479	 DEL: 4
#
# epoch # 24	 SCORE: 0.482	 DEL: 0
#
# epoch # 25	 SCORE: 0.483	 DEL: 6
#
# epoch # 26	 SCORE: 0.495	 DEL: 0
#
# epoch # 28	 SCORE: 0.501	 DEL: 6
#
# epoch # 29	 SCORE: 0.513	 DEL: 1
#
# epoch # 30	 SCORE: 0.525	 DEL: 1
#
# epoch # 34	 SCORE: 0.551	 DEL: 3
#
# epoch # 40	 SCORE: 0.556	 DEL: 6
#
# epoch # 41	 SCORE: 0.557	 DEL: 6
#
# epoch # 42	 SCORE: 0.579	 DEL: 1
#
# epoch # 43	 SCORE: 0.596	 DEL: 4
#
# epoch # 51	 SCORE: 0.615	 DEL: 2
#
# epoch # 52	 SCORE: 0.637	 DEL: 0
#
# REAL SCORE: 0.616666666667
# INIT	 SCORE: 0.410
#
# epoch # 4	 SCORE: 0.428	 DEL: 0
#
# epoch # 18	 SCORE: 0.429	 DEL: 10
#
# epoch # 20	 SCORE: 0.432	 DEL: 9
#
# epoch # 21	 SCORE: 0.440	 DEL: 1
#
# epoch # 23	 SCORE: 0.447	 DEL: 5
#
# epoch # 32	 SCORE: 0.490	 DEL: 7
#
# epoch # 33	 SCORE: 0.499	 DEL: 2
#
# epoch # 37	 SCORE: 0.535	 DEL: 2
#
# epoch # 38	 SCORE: 0.540	 DEL: 12
#
# epoch # 41	 SCORE: 0.580	 DEL: 2
#
# epoch # 44	 SCORE: 0.621	 DEL: 4
#
# epoch # 48	 SCORE: 0.633	 DEL: 3
#
# epoch # 53	 SCORE: 0.637	 DEL: 4
#
# epoch # 60	 SCORE: 0.639	 DEL: 3
#
# epoch # 62	 SCORE: 0.661	 DEL: 2
#
# epoch # 68	 SCORE: 0.665	 DEL: 0
#
# epoch # 69	 SCORE: 0.697	 DEL: 1
#
# epoch # 75	 SCORE: 0.728	 DEL: 1
#
# epoch # 78	 SCORE: 0.730	 DEL: 6
#
# epoch # 86	 SCORE: 0.740	 DEL: 3
#
# REAL SCORE: 0.4
# INIT	 SCORE: 0.391
# epoch # 0	 SCORE: 0.401	 DEL: 3
#
# epoch # 23	 SCORE: 0.408	 DEL: 2
#
# epoch # 28	 SCORE: 0.413	 DEL: 3
#
# epoch # 34	 SCORE: 0.435	 DEL: 1
#
# epoch # 40	 SCORE: 0.440	 DEL: 6
#
# epoch # 43	 SCORE: 0.450	 DEL: 5
#
# epoch # 45	 SCORE: 0.470	 DEL: 0
#
# epoch # 70	 SCORE: 0.475	 DEL: 3
#
# epoch # 86	 SCORE: 0.477	 DEL: 2
#
# epoch # 87	 SCORE: 0.488	 DEL: 1
#
# epoch # 98	 SCORE: 0.492	 DEL: 7
#
# epoch # 99	 SCORE: 0.499	 DEL: 1
#
# epoch # 100	 SCORE: 0.519	 DEL: 1
#
# epoch # 122	 SCORE: 0.525	 DEL: 7
#
# epoch # 127	 SCORE: 0.558	 DEL: 7
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.416
# epoch # 1	 SCORE: 0.474	 DEL: 0
#
# epoch # 2	 SCORE: 0.475	 DEL: 3
#
# epoch # 3	 SCORE: 0.500	 DEL: 3
#
# epoch # 4	 SCORE: 0.501	 DEL: 6
#
# epoch # 5	 SCORE: 0.521	 DEL: 0
#
# epoch # 7	 SCORE: 0.526	 DEL: 4
#
# epoch # 10	 SCORE: 0.541	 DEL: 3
#
# epoch # 11	 SCORE: 0.580	 DEL: 1
#
# epoch # 12	 SCORE: 0.621	 DEL: 1
#
# epoch # 13	 SCORE: 0.643	 DEL: 0
#
# epoch # 14	 SCORE: 0.650	 DEL: 1
#
# epoch # 18	 SCORE: 0.655	 DEL: 2
#
# epoch # 29	 SCORE: 0.671	 DEL: 1
#
# epoch # 33	 SCORE: 0.686	 DEL: 6
#
# epoch # 58	 SCORE: 0.695	 DEL: 5
#
# epoch # 74	 SCORE: 0.699	 DEL: 4
#
# epoch # 78	 SCORE: 0.704	 DEL: 3
#
# epoch # 118	 SCORE: 0.713	 DEL: 3
#
# epoch # 120	 SCORE: 0.750	 DEL: 3
#
# epoch # 121	 SCORE: 0.757	 DEL: 1
#
# REAL SCORE: 0.55
# INIT	 SCORE: 0.579
# epoch # 0	 SCORE: 0.584	 DEL: 2
#
# epoch # 1	 SCORE: 0.617	 DEL: 2
#
#
# epoch # 11	 SCORE: 0.626	 DEL: 5
#
# epoch # 17	 SCORE: 0.628	 DEL: 4
#
# epoch # 27	 SCORE: 0.635	 DEL: 3
#
# epoch # 28	 SCORE: 0.654	 DEL: 7
#
# epoch # 41	 SCORE: 0.658	 DEL: 5
#
# epoch # 49	 SCORE: 0.659	 DEL: 6
#
# epoch # 53	 SCORE: 0.667	 DEL: 6
#
# epoch # 54	 SCORE: 0.668	 DEL: 6
#
# epoch # 61	 SCORE: 0.670	 DEL: 0
#
# epoch # 64	 SCORE: 0.678	 DEL: 2
#
# epoch # 70	 SCORE: 0.683	 DEL: 9
#
# epoch # 82	 SCORE: 0.693	 DEL: 13
#
# epoch # 316	 SCORE: 0.695	 DEL: 5
#
# epoch # 346	 SCORE: 0.698	 DEL: 6
#
# epoch # 432	 SCORE: 0.700	 DEL: 6
#
# epoch # 438	 SCORE: 0.713	 DEL: 3
#
# epoch # 465	 SCORE: 0.724	 DEL: 10
#
# epoch # 482	 SCORE: 0.745	 DEL: 5
#
# REAL SCORE: 0.675
# INIT	 SCORE: 0.571
# epoch # 8	 SCORE: 0.591	 DEL: 0
#
# epoch # 10	 SCORE: 0.630	 DEL: 0
#
# epoch # 231	 SCORE: 0.635	 DEL: 12
#
# REAL SCORE: 0.675
# INIT	 SCORE: 0.589
# epoch # 1	 SCORE: 0.594	 DEL: 0
#
# epoch # 2	 SCORE: 0.612	 DEL: 2
#
# epoch # 4	 SCORE: 0.622	 DEL: 18
#
# epoch # 6	 SCORE: 0.627	 DEL: 4
#
# epoch # 11	 SCORE: 0.642	 DEL: 3
#
# epoch # 19	 SCORE: 0.647	 DEL: 14
#
# epoch # 189	 SCORE: 0.665	 DEL: 13
#
# epoch # 190	 SCORE: 0.665	 DEL: 8
#
# epoch # 196	 SCORE: 0.670	 DEL: 6
#
# epoch # 208	 SCORE: 0.672	 DEL: 10
#
# epoch # 210	 SCORE: 0.678	 DEL: 8
#
# epoch # 233	 SCORE: 0.679	 DEL: 13
#
# epoch # 241	 SCORE: 0.689	 DEL: 9
#
# epoch # 249	 SCORE: 0.703	 DEL: 7
#
# epoch # 267	 SCORE: 0.706	 DEL: 3
#
# epoch # 273	 SCORE: 0.728	 DEL: 6
#
# epoch # 324	 SCORE: 0.804	 DEL: 8
#
#
# REAL SCORE: 0.3
# INIT	 SCORE: 0.411
# epoch # 0	 SCORE: 0.415	 DEL: 12
#
# epoch # 1	 SCORE: 0.417	 DEL: 2
#
# epoch # 3	 SCORE: 0.438	 DEL: 0
#
# epoch # 6	 SCORE: 0.456	 DEL: 2
#
# epoch # 7	 SCORE: 0.458	 DEL: 0
#
# epoch # 8	 SCORE: 0.512	 DEL: 0
#
# epoch # 12	 SCORE: 0.513	 DEL: 8
#
# epoch # 13	 SCORE: 0.522	 DEL: 0
#
# epoch # 14	 SCORE: 0.554	 DEL: 0
#
# epoch # 15	 SCORE: 0.555	 DEL: 1
#
# epoch # 16	 SCORE: 0.602	 DEL: 3
#
# epoch # 19	 SCORE: 0.603	 DEL: 0
#
# epoch # 20	 SCORE: 0.611	 DEL: 0
#
# epoch # 22	 SCORE: 0.625	 DEL: 2
#
# epoch # 25	 SCORE: 0.634	 DEL: 5
#
# epoch # 34	 SCORE: 0.635	 DEL: 10
#
# epoch # 36	 SCORE: 0.644	 DEL: 5
#
# epoch # 41	 SCORE: 0.678	 DEL: 5
#
# epoch # 43	 SCORE: 0.683	 DEL: 3
#
# epoch # 51	 SCORE: 0.686	 DEL: 4
#
# REAL SCORE: 0.325
# INIT	 SCORE: 0.493
#
# epoch # 6	 SCORE: 0.500	 DEL: 7
#
# epoch # 12	 SCORE: 0.504	 DEL: 4
#
# epoch # 22	 SCORE: 0.507	 DEL: 2
#
# epoch # 26	 SCORE: 0.519	 DEL: 1
#
# epoch # 31	 SCORE: 0.524	 DEL: 10
#
# epoch # 34	 SCORE: 0.530	 DEL: 9
#
# epoch # 36	 SCORE: 0.565	 DEL: 11
#
# epoch # 42	 SCORE: 0.608	 DEL: 2
#
# epoch # 43	 SCORE: 0.649	 DEL: 0
#
# epoch # 44	 SCORE: 0.657	 DEL: 1
#
# epoch # 81	 SCORE: 0.662	 DEL: 6
#
# epoch # 130	 SCORE: 0.667	 DEL: 14
#
# epoch # 166	 SCORE: 0.743	 DEL: 6
#
# epoch # 186	 SCORE: 0.754	 DEL: 9
#
# epoch # 223	 SCORE: 0.764	 DEL: 8
#
# epoch # 224	 SCORE: 0.765	 DEL: 4
#
# epoch # 234	 SCORE: 0.770	 DEL: 2
#
# epoch # 245	 SCORE: 0.790	 DEL: 9
#
# epoch # 246	 SCORE: 0.802	 DEL: 5
#
# REAL SCORE: 0.4
# INIT	 SCORE: 0.530
# epoch # 9	 SCORE: 0.541	 DEL: 0
#
# epoch # 10	 SCORE: 0.542	 DEL: 11
#
# epoch # 13	 SCORE: 0.546	 DEL: 2
#
# epoch # 16	 SCORE: 0.552	 DEL: 3
#
# epoch # 25	 SCORE: 0.563	 DEL: 8
#
# epoch # 37	 SCORE: 0.565	 DEL: 7
#
# epoch # 39	 SCORE: 0.591	 DEL: 6
#
# epoch # 43	 SCORE: 0.596	 DEL: 4
#
# epoch # 50	 SCORE: 0.597	 DEL: 2
#
# epoch # 51	 SCORE: 0.603	 DEL: 3
#
# epoch # 54	 SCORE: 0.613	 DEL: 9
#
# epoch # 55	 SCORE: 0.648	 DEL: 1
#
# epoch # 56	 SCORE: 0.649	 DEL: 5
#
# epoch # 62	 SCORE: 0.664	 DEL: 7
#
# epoch # 69	 SCORE: 0.686	 DEL: 7
#
# epoch # 86	 SCORE: 0.691	 DEL: 8
#
# epoch # 102	 SCORE: 0.696	 DEL: 3
#
# epoch # 167	 SCORE: 0.698	 DEL: 6
#
# epoch # 181	 SCORE: 0.735	 DEL: 3
#
#
# REAL SCORE: 0.675
# REAL SCORE: 0.511666666667
# 0.5116666666666666

# %%
Low.init_params(
            k_init          = 100,
            k_split         = 5,
            collect_n       = 20,
            size_dim        = 264,
            num_iteration   = 500,
            learning_rate   = 1,
            min_vec         = 20,
            max_porog       = 0)

Low.get_result()
# Out:
# INIT	 SCORE: 0.440
# epoch # 1	 SCORE: 0.448	 DEL: 1
#
# epoch # 35	 SCORE: 0.468	 DEL: 18
#
# epoch # 106	 SCORE: 0.470	 DEL: 1
#
# epoch # 122	 SCORE: 0.475	 DEL: 6
#
# epoch # 134	 SCORE: 0.475	 DEL: 10
#
#
# REAL SCORE: 0.816666666667
# INIT	 SCORE: 0.426
# epoch # 0	 SCORE: 0.453	 DEL: 3
#
# epoch # 6	 SCORE: 0.460	 DEL: 0
#
# epoch # 9	 SCORE: 0.488	 DEL: 0
#
# epoch # 17	 SCORE: 0.491	 DEL: 2
#
# epoch # 80	 SCORE: 0.494	 DEL: 3
#
# epoch # 81	 SCORE: 0.502	 DEL: 1
#
# epoch # 85	 SCORE: 0.505	 DEL: 3
#
# epoch # 90	 SCORE: 0.507	 DEL: 0
#
# epoch # 91	 SCORE: 0.515	 DEL: 5
#
# epoch # 94	 SCORE: 0.517	 DEL: 5
#
# epoch # 95	 SCORE: 0.520	 DEL: 3
#
# epoch # 99	 SCORE: 0.525	 DEL: 2
#
# epoch # 121	 SCORE: 0.530	 DEL: 4
#
# epoch # 148	 SCORE: 0.535	 DEL: 5
#
# epoch # 234	 SCORE: 0.580	 DEL: 5
#
# epoch # 481	 SCORE: 0.585	 DEL: 3
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.438
# epoch # 0	 SCORE: 0.442	 DEL: 1
#
# epoch # 1	 SCORE: 0.450	 DEL: 5
#
#
# epoch # 16	 SCORE: 0.460	 DEL: 1
#
# epoch # 425	 SCORE: 0.463	 DEL: 6
#
# REAL SCORE: 0.3
# INIT	 SCORE: 0.555
# epoch # 0	 SCORE: 0.587	 DEL: 1
#
# epoch # 3	 SCORE: 0.593	 DEL: 0
#
# epoch # 5	 SCORE: 0.613	 DEL: 1
#
# epoch # 23	 SCORE: 0.618	 DEL: 1
#
# epoch # 109	 SCORE: 0.623	 DEL: 1
#
# epoch # 148	 SCORE: 0.628	 DEL: 12
#
#
# REAL SCORE: 0.3
# INIT	 SCORE: 0.297
# epoch # 8	 SCORE: 0.307	 DEL: 0
#
# epoch # 9	 SCORE: 0.312	 DEL: 3
#
# epoch # 10	 SCORE: 0.323	 DEL: 4
#
# epoch # 12	 SCORE: 0.338	 DEL: 0
#
# epoch # 13	 SCORE: 0.348	 DEL: 11
#
# epoch # 16	 SCORE: 0.375	 DEL: 0
#
# epoch # 19	 SCORE: 0.439	 DEL: 0
#
# epoch # 22	 SCORE: 0.445	 DEL: 2
#
# epoch # 78	 SCORE: 0.452	 DEL: 4
