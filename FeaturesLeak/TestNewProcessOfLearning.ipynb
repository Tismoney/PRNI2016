# %%
import FeaturesLeak as fl
# %matplotlib inline

# %%
test_index =    [[ 5, 10, 13, 18, 44, 45, 56, 67, 70, 79, 90],
                 [ 0, 11, 16, 36, 41, 53, 59, 80, 83, 88],
                 [ 8, 22, 26, 31, 33, 55, 57, 65, 66, 85],
                 [ 1,  2, 35, 39, 42, 54, 63, 69, 76],
                 [24, 25, 27, 43, 49, 60, 61, 74, 78],
                 [ 7, 12, 32, 46, 50, 52, 75, 77, 87],
                 [ 6, 14, 29, 30, 48, 62, 81, 84, 89],
                 [ 3,  4, 15, 38, 40, 51, 58, 68, 73],
                 [17, 20, 21, 23, 37, 71, 82, 92, 93],
                 [ 9, 19, 28, 34, 47, 64, 72, 86, 91]]

index = []
for i in range(10):
    train_index = []
    for j in range(10):
         if i != j: train_index += test_index[j]
    index.append([train_index, test_index[i]])

# %%
grid_cv = fl.StratifiedKFold(n_splits=10,
                          shuffle=True,
                          random_state=0)

eval_cv = fl.StratifiedKFold(n_splits=10,
                          shuffle=True,
                          random_state=1)

# %%
myClass = fl.ChooseSubsection(grid_cv, eval_cv, 
                            k_tr            = 3,
                            k_bag           = 3,
                            collect_n       = 10,
                            size_dim        = 264,
                            num_iteration   = 100,
                            learning_rate   = 10,
                            print_log       = True)

# %%
myClass.init_data()

# %%
myClass.get_seed_result(index)
# Out:
# INIT	 SCORE: 0.639
# epoch # 0	 SCORE: 0.671	 ADD: 30
#
# epoch # 3	 SCORE: 0.718	 ADD: 59
#
# epoch # 9	 SCORE: 0.790	 ADD: 67
#
# epoch # 12	 SCORE: 0.819	 ADD: 75
#
# epoch # 24	 SCORE: 0.839	 ADD: 57
#
# epoch # 65	 SCORE: 0.861	 ADD: 40
#
#
#
# REAL SCORE: 0.566666666667
# INIT	 SCORE: 0.657
# epoch # 0	 SCORE: 0.780	 ADD: 82
#
# epoch # 1	 SCORE: 0.788	 ADD: 80
#
# epoch # 5	 SCORE: 0.798	 ADD: 67
#
# epoch # 8	 SCORE: 0.799	 ADD: 47
#
# epoch # 9	 SCORE: 0.804	 ADD: 78
#
# epoch # 16	 SCORE: 0.838	 ADD: 53
#
# epoch # 21	 SCORE: 0.860	 ADD: 76
#
#
#
# REAL SCORE: 0.6
# INIT	 SCORE: 0.834
# epoch # 5	 SCORE: 0.860	 ADD: 69
#
# epoch # 7	 SCORE: 0.862	 ADD: 82
#
# epoch # 16	 SCORE: 0.877	 ADD: 76
#
# epoch # 17	 SCORE: 0.880	 ADD: 80
#
# epoch # 26	 SCORE: 0.895	 ADD: 76
#
#
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.706
# epoch # 1	 SCORE: 0.724	 ADD: 73
#
# epoch # 4	 SCORE: 0.792	 ADD: 78
#
# epoch # 5	 SCORE: 0.793	 ADD: 23
#
# epoch # 6	 SCORE: 0.846	 ADD: 69
#
# epoch # 9	 SCORE: 0.889	 ADD: 42
#
# epoch # 46	 SCORE: 0.894	 ADD: 69
#
# epoch # 71	 SCORE: 0.899	 ADD: 68
#
#
#
# REAL SCORE: 0.775
# INIT	 SCORE: 0.627
# epoch # 0	 SCORE: 0.670	 ADD: 78
#
# epoch # 4	 SCORE: 0.723	 ADD: 80
#
# epoch # 13	 SCORE: 0.726	 ADD: 11
#
# epoch # 20	 SCORE: 0.729	 ADD: 54
#
# epoch # 38	 SCORE: 0.740	 ADD: 79
#
# epoch # 70	 SCORE: 0.762	 ADD: 25
#
# epoch # 95	 SCORE: 0.776	 ADD: 69
#
#
#
# REAL SCORE: 0.675
# INIT	 SCORE: 0.700
# epoch # 1	 SCORE: 0.782	 ADD: 41
#
# epoch # 2	 SCORE: 0.786	 ADD: 62
#
# epoch # 10	 SCORE: 0.797	 ADD: 70
#
# epoch # 11	 SCORE: 0.822	 ADD: 60
#
# epoch # 15	 SCORE: 0.863	 ADD: 75
#
# epoch # 21	 SCORE: 0.864	 ADD: 0
#
# epoch # 38	 SCORE: 0.869	 ADD: 0
#
# epoch # 66	 SCORE: 0.885	 ADD: 60
#
# epoch # 70	 SCORE: 0.886	 ADD: 22
#
# epoch # 72	 SCORE: 0.912	 ADD: 67
#
# epoch # 96	 SCORE: 0.918	 ADD: 66
#
#
#
# REAL SCORE: 0.55
# INIT	 SCORE: 0.585
# epoch # 3	 SCORE: 0.684	 ADD: 78
#
# epoch # 5	 SCORE: 0.772	 ADD: 82
#
# epoch # 14	 SCORE: 0.778	 ADD: 71
#
# epoch # 15	 SCORE: 0.810	 ADD: 70
#
# epoch # 54	 SCORE: 0.861	 ADD: 65
#
# epoch # 57	 SCORE: 0.889	 ADD: 78
#
#
#
# REAL SCORE: 0.525
# INIT	 SCORE: 0.661
# epoch # 0	 SCORE: 0.701	 ADD: 85
#
# epoch # 1	 SCORE: 0.703	 ADD: 74
#
# epoch # 7	 SCORE: 0.788	 ADD: 68
#
# epoch # 11	 SCORE: 0.809	 ADD: 55
#
# epoch # 14	 SCORE: 0.816	 ADD: 64
#
# epoch # 17	 SCORE: 0.821	 ADD: 63
#
# epoch # 25	 SCORE: 0.826	 ADD: 54
#
# epoch # 28	 SCORE: 0.857	 ADD: 49
#
# epoch # 35	 SCORE: 0.858	 ADD: 39
#
# epoch # 44	 SCORE: 0.863	 ADD: 25
#
# epoch # 51	 SCORE: 0.864	 ADD: 61
#
#
#
# REAL SCORE: 0.525
# INIT	 SCORE: 0.745
# epoch # 3	 SCORE: 0.756	 ADD: 70
#
# epoch # 4	 SCORE: 0.769	 ADD: 84
#
# epoch # 6	 SCORE: 0.783	 ADD: 63
#
# epoch # 15	 SCORE: 0.822	 ADD: 77
#
# epoch # 44	 SCORE: 0.841	 ADD: 65
#
# epoch # 57	 SCORE: 0.847	 ADD: 64
#
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.812
# epoch # 0	 SCORE: 0.853	 ADD: 70
#
# epoch # 4	 SCORE: 0.899	 ADD: 62
#
# epoch # 6	 SCORE: 0.909	 ADD: 81
#
# epoch # 10	 SCORE: 0.912	 ADD: 82
#
# epoch # 34	 SCORE: 0.917	 ADD: 69
#
# epoch # 53	 SCORE: 0.919	 ADD: 64
#
#
#
# REAL SCORE: 0.65
# REAL SCORE: 0.601666666667
# 0.60166666666666679

# %%
myClass.num_iteration = 200

# %%
myClass.get_seed_result(index)
# Out:
# INIT	 SCORE: 0.639
# epoch # 0	 SCORE: 0.730	 ADD: 70
#
# epoch # 1	 SCORE: 0.795	 ADD: 61
#
# epoch # 5	 SCORE: 0.795	 ADD: 77
#
# epoch # 11	 SCORE: 0.836	 ADD: 80
#
# epoch # 45	 SCORE: 0.842	 ADD: 15
#
# epoch # 50	 SCORE: 0.846	 ADD: 58
#
# epoch # 89	 SCORE: 0.855	 ADD: 67
#
# epoch # 164	 SCORE: 0.858	 ADD: 53
#
#
#
# REAL SCORE: 0.9
# INIT	 SCORE: 0.657
# epoch # 3	 SCORE: 0.714	 ADD: 77
#
# epoch # 8	 SCORE: 0.788	 ADD: 81
#
# epoch # 11	 SCORE: 0.806	 ADD: 67
#
# epoch # 14	 SCORE: 0.818	 ADD: 61
#
# epoch # 17	 SCORE: 0.823	 ADD: 75
#
# epoch # 24	 SCORE: 0.832	 ADD: 66
#
# epoch # 32	 SCORE: 0.843	 ADD: 53
#
# epoch # 35	 SCORE: 0.847	 ADD: 52
#
# epoch # 125	 SCORE: 0.853	 ADD: 58
#
# epoch # 142	 SCORE: 0.857	 ADD: 63
#
#
#
# REAL SCORE: 0.9
# INIT	 SCORE: 0.834
# epoch # 5	 SCORE: 0.860	 ADD: 69
#
# epoch # 6	 SCORE: 0.894	 ADD: 77
#
# epoch # 14	 SCORE: 0.895	 ADD: 8
#
# epoch # 15	 SCORE: 0.902	 ADD: 79
#
# epoch # 17	 SCORE: 0.925	 ADD: 59
#
# epoch # 20	 SCORE: 0.935	 ADD: 73
#
# epoch # 26	 SCORE: 0.940	 ADD: 55
#
# epoch # 60	 SCORE: 0.948	 ADD: 13
#
# epoch # 74	 SCORE: 0.958	 ADD: 56
#
#
#
# REAL SCORE: 0.4
# INIT	 SCORE: 0.706
# epoch # 5	 SCORE: 0.752	 ADD: 72
#
# epoch # 12	 SCORE: 0.807	 ADD: 41
#
# epoch # 14	 SCORE: 0.839	 ADD: 76
#
# epoch # 15	 SCORE: 0.844	 ADD: 75
#
# epoch # 19	 SCORE: 0.859	 ADD: 65
#
# epoch # 42	 SCORE: 0.869	 ADD: 68
#
# epoch # 45	 SCORE: 0.873	 ADD: 78
#
# epoch # 70	 SCORE: 0.878	 ADD: 76
#
# epoch # 157	 SCORE: 0.879	 ADD: 77
#
# epoch # 173	 SCORE: 0.885	 ADD: 72
#
#
#
# REAL SCORE: 0.875
# INIT	 SCORE: 0.627
# epoch # 0	 SCORE: 0.698	 ADD: 72
#
# epoch # 10	 SCORE: 0.746	 ADD: 70
#
# epoch # 13	 SCORE: 0.795	 ADD: 62
#
# epoch # 125	 SCORE: 0.797	 ADD: 64
#
# epoch # 126	 SCORE: 0.815	 ADD: 69
#
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.700
# epoch # 4	 SCORE: 0.762	 ADD: 78
#
# epoch # 5	 SCORE: 0.801	 ADD: 77
#
# epoch # 42	 SCORE: 0.809	 ADD: 47
#
#
#
# REAL SCORE: 0.575
# INIT	 SCORE: 0.585
# epoch # 0	 SCORE: 0.694	 ADD: 66
#
# epoch # 3	 SCORE: 0.742	 ADD: 57
#
# epoch # 5	 SCORE: 0.755	 ADD: 69
#
# epoch # 7	 SCORE: 0.765	 ADD: 81
#
# epoch # 8	 SCORE: 0.794	 ADD: 76
#
# epoch # 9	 SCORE: 0.831	 ADD: 67
#
# epoch # 14	 SCORE: 0.841	 ADD: 79
#
# epoch # 16	 SCORE: 0.845	 ADD: 42
#
# epoch # 19	 SCORE: 0.846	 ADD: 62
#
# epoch # 21	 SCORE: 0.851	 ADD: 66
#
# epoch # 33	 SCORE: 0.856	 ADD: 35
#
# epoch # 137	 SCORE: 0.878	 ADD: 43
#
# epoch # 148	 SCORE: 0.882	 ADD: 43
#
# epoch # 182	 SCORE: 0.887	 ADD: 59
#
#
#
# REAL SCORE: 0.55
# INIT	 SCORE: 0.661
# epoch # 2	 SCORE: 0.701	 ADD: 85
#
# epoch # 3	 SCORE: 0.749	 ADD: 40
#
# epoch # 6	 SCORE: 0.786	 ADD: 64
#
# epoch # 9	 SCORE: 0.787	 ADD: 73
#
# epoch # 15	 SCORE: 0.790	 ADD: 37
#
# epoch # 20	 SCORE: 0.841	 ADD: 67
#
# epoch # 32	 SCORE: 0.847	 ADD: 59
#
# epoch # 45	 SCORE: 0.848	 ADD: 66
#
# epoch # 55	 SCORE: 0.870	 ADD: 45
#
# epoch # 79	 SCORE: 0.873	 ADD: 52
#
# epoch # 88	 SCORE: 0.875	 ADD: 65
#
# epoch # 129	 SCORE: 0.881	 ADD: 59
#
# epoch # 187	 SCORE: 0.894	 ADD: 36
#
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.745
# epoch # 1	 SCORE: 0.769	 ADD: 63
#
# epoch # 3	 SCORE: 0.778	 ADD: 77
#
# epoch # 6	 SCORE: 0.837	 ADD: 25
#
# epoch # 7	 SCORE: 0.866	 ADD: 78
#
# epoch # 15	 SCORE: 0.873	 ADD: 29
#
# epoch # 31	 SCORE: 0.875	 ADD: 50
#
# epoch # 36	 SCORE: 0.882	 ADD: 58
#
# epoch # 39	 SCORE: 0.887	 ADD: 76
#
# epoch # 53	 SCORE: 0.891	 ADD: 10
#
# epoch # 74	 SCORE: 0.896	 ADD: 69
#
#
#
# REAL SCORE: 0.3
# INIT	 SCORE: 0.812
# epoch # 7	 SCORE: 0.824	 ADD: 28
#
# epoch # 13	 SCORE: 0.843	 ADD: 69
#
# epoch # 24	 SCORE: 0.845	 ADD: 77
#
# epoch # 25	 SCORE: 0.849	 ADD: 63
#
# epoch # 37	 SCORE: 0.860	 ADD: 80
#
# epoch # 39	 SCORE: 0.869	 ADD: 80
#
# epoch # 49	 SCORE: 0.909	 ADD: 61
#
# epoch # 52	 SCORE: 0.914	 ADD: 78
#
# epoch # 89	 SCORE: 0.920	 ADD: 60
#
#
#
# REAL SCORE: 0.75
# REAL SCORE: 0.655
# 0.65500000000000003
