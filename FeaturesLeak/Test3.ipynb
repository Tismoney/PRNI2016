# %%
import FeaturesLeak as fl
# %matplotlib inline

# %%
grid_cv = fl.StratifiedKFold(n_splits=10,
                          shuffle=True,
                          random_state=0)

eval_cv = fl.StratifiedKFold(n_splits=10,
                          shuffle=True,
                          random_state=1)

# %%
myClass = fl.ChooseSubsection(grid_cv, eval_cv, 
                            k_tr            = 3,
                            k_bag           = 3,
                            test_size       = 0.1,
                            collect_n       = 100,
                            size_dim        = 264,
                            num_iteration   = 700,
                            learning_rate   = 0.2,
                            print_log       = True,
                            max_vec         = 12)

# %%
myClass.init_data()

# %%
myClass.get_seed_result()
# Out:
# INIT	 SCORE: 0.742
# epoch # 121	 SCORE: 0.768	 ADD: 82
#
# epoch # 199	 SCORE: 0.781	 ADD: 67
#
# epoch # 200	 SCORE: 0.814	 ADD: 78
#
#
# REAL SCORE: 0.716666666667
# INIT	 SCORE: 0.733
# epoch # 96	 SCORE: 0.802	 ADD: 78
#
# epoch # 304	 SCORE: 0.832	 ADD: 67
#
#
#
# REAL SCORE: 0.7
# INIT	 SCORE: 0.671
# epoch # 49	 SCORE: 0.718	 ADD: 80
#
# epoch # 119	 SCORE: 0.829	 ADD: 81
#
# epoch # 194	 SCORE: 0.862	 ADD: 79
#
#
# REAL SCORE: 0.8
# INIT	 SCORE: 0.710
# epoch # 88	 SCORE: 0.772	 ADD: 70
#
# epoch # 184	 SCORE: 0.842	 ADD: 78
#
# epoch # 190	 SCORE: 0.846	 ADD: 67
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.740
# epoch # 113	 SCORE: 0.762	 ADD: 84
#
# epoch # 124	 SCORE: 0.768	 ADD: 82
#
# epoch # 169	 SCORE: 0.804	 ADD: 78
#
#
# REAL SCORE: 0.75
# INIT	 SCORE: 0.707
# epoch # 110	 SCORE: 0.784	 ADD: 61
#
# epoch # 320	 SCORE: 0.826	 ADD: 68
#
# epoch # 366	 SCORE: 0.829	 ADD: 83
#
#
# REAL SCORE: 0.6
# INIT	 SCORE: 0.706
# epoch # 198	 SCORE: 0.746	 ADD: 79
#
# epoch # 222	 SCORE: 0.816	 ADD: 69
#
# epoch # 323	 SCORE: 0.832	 ADD: 80
#
#
# REAL SCORE: 0.775
# INIT	 SCORE: 0.615
# epoch # 96	 SCORE: 0.725	 ADD: 81
#
# epoch # 123	 SCORE: 0.739	 ADD: 68
#
# epoch # 136	 SCORE: 0.823	 ADD: 80
#
#
# REAL SCORE: 0.775
# INIT	 SCORE: 0.706
# epoch # 51	 SCORE: 0.733	 ADD: 79
#
# epoch # 73	 SCORE: 0.743	 ADD: 82
#
# epoch # 116	 SCORE: 0.898	 ADD: 68
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.712
# epoch # 94	 SCORE: 0.787	 ADD: 84
#
# epoch # 98	 SCORE: 0.800	 ADD: 70
#
# epoch # 157	 SCORE: 0.815	 ADD: 69
#
#
# REAL SCORE: 0.775

# %%
myClass.get_seed_result()
# Out:
# INIT	 SCORE: 0.671
# epoch # 114	 SCORE: 0.767	 ADD: 78
#
# epoch # 121	 SCORE: 0.804	 ADD: 81
#
# epoch # 231	 SCORE: 0.810	 ADD: 76
#
#
# REAL SCORE: 0.716666666667
# INIT	 SCORE: 0.642
# epoch # 118	 SCORE: 0.778	 ADD: 82
#
# epoch # 138	 SCORE: 0.809	 ADD: 79
#
# epoch # 154	 SCORE: 0.814	 ADD: 78
#
#
# REAL SCORE: 0.7
# INIT	 SCORE: 0.746
# epoch # 103	 SCORE: 0.770	 ADD: 79
#
# epoch # 134	 SCORE: 0.813	 ADD: 84
#
# epoch # 163	 SCORE: 0.849	 ADD: 68
#
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.641
# epoch # 92	 SCORE: 0.713	 ADD: 70
#
# epoch # 125	 SCORE: 0.854	 ADD: 78
#
# epoch # 190	 SCORE: 0.891	 ADD: 80
#
#
# REAL SCORE: 0.775
# INIT	 SCORE: 0.568
# epoch # 125	 SCORE: 0.775	 ADD: 82
#
# epoch # 229	 SCORE: 0.829	 ADD: 69
#
# epoch # 273	 SCORE: 0.834	 ADD: 80
#
#
# REAL SCORE: 0.525
# INIT	 SCORE: 0.739
# epoch # 116	 SCORE: 0.756	 ADD: 79
#
# epoch # 197	 SCORE: 0.786	 ADD: 81
#
# epoch # 329	 SCORE: 0.810	 ADD: 69
#
#
# REAL SCORE: 0.8
# INIT	 SCORE: 0.615
# epoch # 111	 SCORE: 0.709	 ADD: 81
#
# epoch # 115	 SCORE: 0.811	 ADD: 82
#
# epoch # 128	 SCORE: 0.829	 ADD: 80
#
#
# REAL SCORE: 0.525
# INIT	 SCORE: 0.670
# epoch # 70	 SCORE: 0.797	 ADD: 69
#
# epoch # 251	 SCORE: 0.801	 ADD: 81
#
# epoch # 352	 SCORE: 0.807	 ADD: 61
#
#
# REAL SCORE: 0.9
# INIT	 SCORE: 0.780
# epoch # 225	 SCORE: 0.846	 ADD: 69
#
# epoch # 476	 SCORE: 0.847	 ADD: 65
#
# epoch # 520	 SCORE: 0.879	 ADD: 83
#
#
# REAL SCORE: 0.575
# INIT	 SCORE: 0.809
# epoch # 68	 SCORE: 0.839	 ADD: 83
#
# epoch # 143	 SCORE: 0.855	 ADD: 78
#
# epoch # 493	 SCORE: 0.863	 ADD: 61
#
#
# REAL SCORE: 0.525

# %%
myClass.test_index
# Out:
# [array([ 5, 10, 13, 18, 44, 45, 56, 67, 70, 79, 90]),
#  array([ 0, 11, 16, 36, 41, 53, 59, 80, 83, 88]),
#  array([ 8, 22, 26, 31, 33, 55, 57, 65, 66, 85]),
#  array([ 1,  2, 35, 39, 42, 54, 63, 69, 76]),
#  array([24, 25, 27, 43, 49, 60, 61, 74, 78]),
#  array([ 7, 12, 32, 46, 50, 52, 75, 77, 87]),
#  array([ 6, 14, 29, 30, 48, 62, 81, 84, 89]),
#  array([ 3,  4, 15, 38, 40, 51, 58, 68, 73]),
#  array([17, 20, 21, 23, 37, 71, 82, 92, 93]),
#  array([ 9, 19, 28, 34, 47, 64, 72, 86, 91])]
