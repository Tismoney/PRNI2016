# %%
import FeaturesLeak as fl
# %matplotlib inline

# %%
test_index =    [[ 5, 10, 13, 18, 44, 45, 56, 67, 70, 79, 90],
                 [ 0, 11, 16, 36, 41, 53, 59, 80, 83, 88],
                 [ 8, 22, 26, 31, 33, 55, 57, 65, 66, 85],
                 [ 1,  2, 35, 39, 42, 54, 63, 69, 76],
                 [24, 25, 27, 43, 49, 60, 61, 74, 78],
                 [ 7, 12, 32, 46, 50, 52, 75, 77, 87],
                 [ 6, 14, 29, 30, 48, 62, 81, 84, 89],
                 [ 3,  4, 15, 38, 40, 51, 58, 68, 73],
                 [17, 20, 21, 23, 37, 71, 82, 92, 93],
                 [ 9, 19, 28, 34, 47, 64, 72, 86, 91]]

index = []
for i in range(10):
    train_index = []
    for j in range(10):
         if i != j: train_index += test_index[j]
    index.append([train_index, test_index[i]])

# %%
grid_cv = fl.StratifiedKFold(n_splits=10,
                          shuffle=True,
                          random_state=0)

eval_cv = fl.StratifiedKFold(n_splits=10,
                          shuffle=True,
                          random_state=1)

# %%
myClass = fl.ChooseSubsection(grid_cv, eval_cv, 
                            k_tr            = 3,
                            k_bag           = 3,
                            test_size       = 0.1,
                            collect_n       = 10,
                            size_dim        = 264,
                            num_iteration   = 400,
                            learning_rate   = 0.3,
                            print_log       = True)

# %%
myClass.init_data()

# %%
myClass.get_seed_result(index)
# Out:
# INIT	 SCORE: 0.500
# epoch # 78	 SCORE: 0.574	 ADD: 86
#
# epoch # 123	 SCORE: 0.575	 ADD: 84
#
# epoch # 184	 SCORE: 0.601	 ADD: 72
#
# epoch # 188	 SCORE: 0.613	 ADD: 82
#
# epoch # 246	 SCORE: 0.638	 ADD: 70
#
# epoch # 335	 SCORE: 0.670	 ADD: 62
#
#
#
# REAL SCORE: 0.733333333333
# INIT	 SCORE: 0.500
# epoch # 86	 SCORE: 0.605	 ADD: 78
#
# epoch # 107	 SCORE: 0.666	 ADD: 81
#
# epoch # 125	 SCORE: 0.678	 ADD: 67
#
# epoch # 162	 SCORE: 0.720	 ADD: 54
#
# epoch # 192	 SCORE: 0.723	 ADD: 79
#
#
#
# REAL SCORE: 0.4
# INIT	 SCORE: 0.500
# epoch # 58	 SCORE: 0.680	 ADD: 86
#
# epoch # 112	 SCORE: 0.761	 ADD: 74
#
# epoch # 115	 SCORE: 0.773	 ADD: 83
#
# epoch # 139	 SCORE: 0.778	 ADD: 83
#
# epoch # 342	 SCORE: 0.780	 ADD: 64
#
#
#
# REAL SCORE: 0.6
# INIT	 SCORE: 0.500
# epoch # 43	 SCORE: 0.695	 ADD: 86
#
# epoch # 104	 SCORE: 0.695	 ADD: 68
#
# epoch # 146	 SCORE: 0.708	 ADD: 84
#
# epoch # 276	 SCORE: 0.725	 ADD: 66
#
# epoch # 302	 SCORE: 0.747	 ADD: 77
#
# epoch # 308	 SCORE: 0.767	 ADD: 70
#
# epoch # 364	 SCORE: 0.788	 ADD: 76
#
#
#
# REAL SCORE: 0.875
# INIT	 SCORE: 0.500
# epoch # 125	 SCORE: 0.566	 ADD: 73
#
# epoch # 136	 SCORE: 0.705	 ADD: 49
#
# epoch # 137	 SCORE: 0.740	 ADD: 68
#
# epoch # 139	 SCORE: 0.767	 ADD: 79
#
# epoch # 168	 SCORE: 0.771	 ADD: 70
#
# epoch # 389	 SCORE: 0.778	 ADD: 69
#
#
#
# REAL SCORE: 0.625
# INIT	 SCORE: 0.500
# epoch # 100	 SCORE: 0.620	 ADD: 83
#
# epoch # 109	 SCORE: 0.621	 ADD: 84
#
# epoch # 150	 SCORE: 0.641	 ADD: 79
#
# epoch # 176	 SCORE: 0.646	 ADD: 82
#
# epoch # 189	 SCORE: 0.661	 ADD: 71
#
# epoch # 206	 SCORE: 0.674	 ADD: 60
#
# epoch # 263	 SCORE: 0.714	 ADD: 63
#
# epoch # 276	 SCORE: 0.781	 ADD: 67
#
# epoch # 290	 SCORE: 0.787	 ADD: 65
#
# epoch # 338	 SCORE: 0.792	 ADD: 60
#
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.500
# epoch # 55	 SCORE: 0.663	 ADD: 86
#
# epoch # 106	 SCORE: 0.748	 ADD: 61
#
# epoch # 137	 SCORE: 0.805	 ADD: 41
#
# epoch # 194	 SCORE: 0.823	 ADD: 55
#
# epoch # 195	 SCORE: 0.827	 ADD: 79
#
# epoch # 244	 SCORE: 0.883	 ADD: 62
#
#
#
# REAL SCORE: 0.525
# INIT	 SCORE: 0.500
# epoch # 65	 SCORE: 0.665	 ADD: 85
#
# epoch # 80	 SCORE: 0.804	 ADD: 85
#
# epoch # 142	 SCORE: 0.810	 ADD: 75
#
# epoch # 145	 SCORE: 0.843	 ADD: 70
#
# epoch # 168	 SCORE: 0.872	 ADD: 64
#
# epoch # 222	 SCORE: 0.878	 ADD: 64
#
#
#
# REAL SCORE: 0.675
# INIT	 SCORE: 0.500
# epoch # 66	 SCORE: 0.749	 ADD: 86
#
# epoch # 114	 SCORE: 0.752	 ADD: 85
#
# epoch # 147	 SCORE: 0.753	 ADD: 63
#
# epoch # 153	 SCORE: 0.782	 ADD: 74
#
# epoch # 165	 SCORE: 0.811	 ADD: 63
#
# epoch # 173	 SCORE: 0.856	 ADD: 67
#
# epoch # 269	 SCORE: 0.861	 ADD: 66
#
#
#
# REAL SCORE: 0.45
# INIT	 SCORE: 0.500
# epoch # 64	 SCORE: 0.715	 ADD: 86
#
# epoch # 81	 SCORE: 0.728	 ADD: 84
#
# epoch # 107	 SCORE: 0.755	 ADD: 79
#
# epoch # 110	 SCORE: 0.766	 ADD: 77
#
# epoch # 116	 SCORE: 0.780	 ADD: 69
#
# epoch # 158	 SCORE: 0.844	 ADD: 61
#
# epoch # 182	 SCORE: 0.863	 ADD: 80
#
# epoch # 188	 SCORE: 0.875	 ADD: 54
#
# epoch # 201	 SCORE: 0.882	 ADD: 74
#
# epoch # 288	 SCORE: 0.919	 ADD: 39
#
#
#
# REAL SCORE: 0.2
# REAL SCORE: 0.573333333333
# 0.57333333333333347
