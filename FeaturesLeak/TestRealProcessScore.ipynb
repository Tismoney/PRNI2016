# %%
import FeaturesLeak as fl
# %matplotlib inline

# %%
test_index =    [[ 5, 10, 13, 18, 44, 45, 56, 67, 70, 79, 90],
                 [ 0, 11, 16, 36, 41, 53, 59, 80, 83, 88],
                 [ 8, 22, 26, 31, 33, 55, 57, 65, 66, 85],
                 [ 1,  2, 35, 39, 42, 54, 63, 69, 76],
                 [24, 25, 27, 43, 49, 60, 61, 74, 78],
                 [ 7, 12, 32, 46, 50, 52, 75, 77, 87],
                 [ 6, 14, 29, 30, 48, 62, 81, 84, 89],
                 [ 3,  4, 15, 38, 40, 51, 58, 68, 73],
                 [17, 20, 21, 23, 37, 71, 82, 92, 93],
                 [ 9, 19, 28, 34, 47, 64, 72, 86, 91]]

index = []
for i in range(10):
    train_index = []
    for j in range(10):
         if i != j: train_index += test_index[j]
    index.append([train_index, test_index[i]])

# %%
grid_cv = fl.StratifiedKFold(n_splits=10,
                          shuffle=True,
                          random_state=0)

eval_cv = fl.StratifiedKFold(n_splits=10,
                          shuffle=True,
                          random_state=1)

# %%
myClass = fl.ChooseSubsection(grid_cv, eval_cv, 
                            k_tr            = 3,
                            k_bag           = 3,
                            test_size       = 0.1,
                            collect_n       = 10,
                            size_dim        = 264,
                            num_iteration   = 400,
                            learning_rate   = 0.3,
                            print_log       = True)

# %%
myClass.init_data()

# %%
myClass.get_seed_result(index)
# Out:
# INIT	 SCORE: 0.639
# epoch # 54	 SCORE: 0.680	 ADD: 84
#
# epoch # 64	 SCORE: 0.686	 ADD: 80
#
# epoch # 68	 SCORE: 0.704	 ADD: 81
#
# epoch # 92	 SCORE: 0.711	 ADD: 70
#
# epoch # 190	 SCORE: 0.754	 ADD: 62
#
# epoch # 194	 SCORE: 0.773	 ADD: 75
#
# epoch # 292	 SCORE: 0.779	 ADD: 58
#
# epoch # 303	 SCORE: 0.780	 ADD: 77
#
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.657
# epoch # 40	 SCORE: 0.684	 ADD: 80
#
# epoch # 53	 SCORE: 0.777	 ADD: 82
#
# epoch # 63	 SCORE: 0.791	 ADD: 70
#
# epoch # 190	 SCORE: 0.828	 ADD: 69
#
# epoch # 210	 SCORE: 0.838	 ADD: 77
#
# epoch # 325	 SCORE: 0.843	 ADD: 78
#
#
#
# REAL SCORE: 0.9
# INIT	 SCORE: 0.834
# epoch # 68	 SCORE: 0.852	 ADD: 67
#
# epoch # 137	 SCORE: 0.878	 ADD: 67
#
# epoch # 168	 SCORE: 0.924	 ADD: 65
#
#
#
# REAL SCORE: 0.6
# INIT	 SCORE: 0.706
# epoch # 55	 SCORE: 0.845	 ADD: 79
#
# epoch # 177	 SCORE: 0.922	 ADD: 70
#
#
#
# REAL SCORE: 0.675
# INIT	 SCORE: 0.627
# epoch # 52	 SCORE: 0.647	 ADD: 77
#
# epoch # 59	 SCORE: 0.672	 ADD: 72
#
# epoch # 66	 SCORE: 0.682	 ADD: 78
#
# epoch # 100	 SCORE: 0.740	 ADD: 68
#
# epoch # 105	 SCORE: 0.741	 ADD: 67
#
# epoch # 130	 SCORE: 0.760	 ADD: 65
#
# epoch # 179	 SCORE: 0.776	 ADD: 76
#
# epoch # 216	 SCORE: 0.778	 ADD: 62
#
#
#
# REAL SCORE: 0.75
# INIT	 SCORE: 0.700
# epoch # 68	 SCORE: 0.711	 ADD: 83
#
# epoch # 71	 SCORE: 0.740	 ADD: 61
#
# epoch # 78	 SCORE: 0.784	 ADD: 78
#
# epoch # 103	 SCORE: 0.799	 ADD: 65
#
# epoch # 163	 SCORE: 0.832	 ADD: 66
#
# epoch # 198	 SCORE: 0.835	 ADD: 80
#
# epoch # 205	 SCORE: 0.851	 ADD: 68
#
# epoch # 216	 SCORE: 0.857	 ADD: 67
#
# epoch # 223	 SCORE: 0.864	 ADD: 77
#
# epoch # 236	 SCORE: 0.876	 ADD: 72
#
#
#
# REAL SCORE: 0.675
# INIT	 SCORE: 0.585
# epoch # 70	 SCORE: 0.694	 ADD: 84
#
# epoch # 99	 SCORE: 0.799	 ADD: 79
#
#
#
# REAL SCORE: 0.65
# INIT	 SCORE: 0.661
# epoch # 45	 SCORE: 0.701	 ADD: 85
#
# epoch # 105	 SCORE: 0.711	 ADD: 84
#
# epoch # 146	 SCORE: 0.827	 ADD: 60
#
#
#
# REAL SCORE: 0.675
# INIT	 SCORE: 0.745
# epoch # 72	 SCORE: 0.751	 ADD: 64
#
# epoch # 88	 SCORE: 0.810	 ADD: 78
#
# epoch # 304	 SCORE: 0.821	 ADD: 69
#
# epoch # 307	 SCORE: 0.829	 ADD: 61
#
# epoch # 335	 SCORE: 0.844	 ADD: 79
#
#
#
# REAL SCORE: 0.75
# INIT	 SCORE: 0.812
# epoch # 48	 SCORE: 0.814	 ADD: 78
#
# epoch # 84	 SCORE: 0.849	 ADD: 83
#
# epoch # 111	 SCORE: 0.881	 ADD: 83
#
# epoch # 120	 SCORE: 0.882	 ADD: 70
#
# epoch # 131	 SCORE: 0.910	 ADD: 60
#
# epoch # 336	 SCORE: 0.925	 ADD: 41
#
#
#
# REAL SCORE: 0.65
# REAL SCORE: 0.6975
# 0.69750000000000001
