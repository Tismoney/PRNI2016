# %%
import FeaturesLeak as fl
# %matplotlib inline

# %%
grid_cv = fl.StratifiedKFold(n_splits=10,
                          shuffle=True,
                          random_state=0)

eval_cv = fl.StratifiedKFold(n_splits=10,
                          shuffle=True,
                          random_state=1)

# %%
myClass = fl.ChooseSubsection(grid_cv, eval_cv, 
                            k_tr            = 3,
                            k_bag           = 3,
                            test_size       = 0.1,
                            collect_n       = 100,
                            size_dim        = 264,
                            num_iteration   = 700,
                            learning_rate   = 0.2,
                            print_log       = True)

# %%
myClass.init_data()

# %%
for i in range(20):
    myClass.split_data()
    myClass.fit_choose_vec()
    myClass.get_result()
# Out:
# INIT	 SCORE: 0.672
# epoch # 58	 SCORE: 0.685	 ADD: 85
#
# epoch # 105	 SCORE: 0.709	 ADD: 79
#
# epoch # 147	 SCORE: 0.724	 ADD: 82
#
# epoch # 185	 SCORE: 0.735	 ADD: 68
#
# epoch # 202	 SCORE: 0.741	 ADD: 81
#
# epoch # 204	 SCORE: 0.800	 ADD: 62
#
# epoch # 323	 SCORE: 0.835	 ADD: 59
#
# epoch # 499	 SCORE: 0.841	 ADD: 60
#
#
#
# REAL SCORE: 0.547619047619
# INIT	 SCORE: 0.728
# epoch # 115	 SCORE: 0.787	 ADD: 78
#
# epoch # 196	 SCORE: 0.817	 ADD: 68
#
# epoch # 264	 SCORE: 0.822	 ADD: 77
#
# epoch # 285	 SCORE: 0.830	 ADD: 69
#
# epoch # 325	 SCORE: 0.858	 ADD: 60
#
# epoch # 399	 SCORE: 0.867	 ADD: 66
#
#
#
# REAL SCORE: 0.619047619048
# INIT	 SCORE: 0.666
# epoch # 67	 SCORE: 0.766	 ADD: 76
#
# epoch # 97	 SCORE: 0.801	 ADD: 83
#
# epoch # 281	 SCORE: 0.838	 ADD: 67
#
# epoch # 283	 SCORE: 0.840	 ADD: 78
#
# epoch # 292	 SCORE: 0.850	 ADD: 68
#
# epoch # 595	 SCORE: 0.854	 ADD: 39
#
# epoch # 629	 SCORE: 0.859	 ADD: 60
#
# epoch # 683	 SCORE: 0.865	 ADD: 74
#
#
#
# REAL SCORE: 0.52380952381
# INIT	 SCORE: 0.698
# epoch # 62	 SCORE: 0.776	 ADD: 70
#
# epoch # 203	 SCORE: 0.777	 ADD: 77
#
# epoch # 285	 SCORE: 0.783	 ADD: 83
#
# epoch # 298	 SCORE: 0.795	 ADD: 69
#
# epoch # 301	 SCORE: 0.796	 ADD: 62
#
# epoch # 382	 SCORE: 0.814	 ADD: 80
#
# epoch # 452	 SCORE: 0.819	 ADD: 74
#
# epoch # 455	 SCORE: 0.838	 ADD: 73
#
# epoch # 654	 SCORE: 0.844	 ADD: 77
#
#
#
# REAL SCORE: 0.791666666667
# INIT	 SCORE: 0.733
# epoch # 168	 SCORE: 0.743	 ADD: 79
#
# epoch # 320	 SCORE: 0.768	 ADD: 65
#
# epoch # 521	 SCORE: 0.786	 ADD: 69
#
# epoch # 528	 SCORE: 0.881	 ADD: 62
#
# epoch # 595	 SCORE: 0.881	 ADD: 70
#
#
#
# REAL SCORE: 0.75
# INIT	 SCORE: 0.551
# epoch # 67	 SCORE: 0.746	 ADD: 82
#
# epoch # 126	 SCORE: 0.788	 ADD: 78
#
# epoch # 187	 SCORE: 0.805	 ADD: 68
#
# epoch # 215	 SCORE: 0.809	 ADD: 80
#
# epoch # 219	 SCORE: 0.812	 ADD: 78
#
# epoch # 313	 SCORE: 0.815	 ADD: 66
#
# epoch # 329	 SCORE: 0.819	 ADD: 77
#
# epoch # 402	 SCORE: 0.831	 ADD: 77
#
# epoch # 488	 SCORE: 0.842	 ADD: 62
#
# epoch # 552	 SCORE: 0.848	 ADD: 73
#
#
#
# REAL SCORE: 0.875
# INIT	 SCORE: 0.753
# epoch # 167	 SCORE: 0.762	 ADD: 47
#
# epoch # 182	 SCORE: 0.771	 ADD: 81
#
# epoch # 290	 SCORE: 0.775	 ADD: 76
#
# epoch # 339	 SCORE: 0.781	 ADD: 57
#
# epoch # 418	 SCORE: 0.782	 ADD: 81
#
# epoch # 479	 SCORE: 0.794	 ADD: 68
#
# epoch # 515	 SCORE: 0.800	 ADD: 67
#
# epoch # 615	 SCORE: 0.807	 ADD: 69
#
#
#
# REAL SCORE: 0.625
# INIT	 SCORE: 0.732
# epoch # 73	 SCORE: 0.748	 ADD: 84
#
# epoch # 103	 SCORE: 0.782	 ADD: 84
#
# epoch # 134	 SCORE: 0.789	 ADD: 82
#
# epoch # 214	 SCORE: 0.798	 ADD: 78
#
# epoch # 315	 SCORE: 0.835	 ADD: 73
#
# epoch # 450	 SCORE: 0.839	 ADD: 54
#
# epoch # 549	 SCORE: 0.859	 ADD: 69
#
#
#
# REAL SCORE: 0.708333333333
# INIT	 SCORE: 0.682
# epoch # 60	 SCORE: 0.718	 ADD: 84
#
# epoch # 124	 SCORE: 0.822	 ADD: 67
#
# epoch # 155	 SCORE: 0.830	 ADD: 83
#
# epoch # 175	 SCORE: 0.835	 ADD: 82
#
# epoch # 180	 SCORE: 0.855	 ADD: 60
#
# epoch # 189	 SCORE: 0.860	 ADD: 77
#
# epoch # 276	 SCORE: 0.880	 ADD: 66
#
# epoch # 387	 SCORE: 0.890	 ADD: 66
#
#
#
# REAL SCORE: 0.833333333333
# INIT	 SCORE: 0.546
# epoch # 103	 SCORE: 0.649	 ADD: 80
#
# epoch # 108	 SCORE: 0.716	 ADD: 79
#
# epoch # 146	 SCORE: 0.730	 ADD: 68
#
# epoch # 150	 SCORE: 0.770	 ADD: 80
#
# epoch # 169	 SCORE: 0.857	 ADD: 79
#
#
#
# REAL SCORE: 0.8125
# INIT	 SCORE: 0.703
# epoch # 66	 SCORE: 0.790	 ADD: 80
#
# epoch # 115	 SCORE: 0.857	 ADD: 81
#
# epoch # 241	 SCORE: 0.873	 ADD: 65
#
# epoch # 313	 SCORE: 0.897	 ADD: 78
#
# epoch # 365	 SCORE: 0.910	 ADD: 69
#
# epoch # 466	 SCORE: 0.920	 ADD: 71
#
# epoch # 503	 SCORE: 0.930	 ADD: 44
#
# epoch # 554	 SCORE: 0.945	 ADD: 70
#
#
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.720
# epoch # 38	 SCORE: 0.735	 ADD: 84
#
# epoch # 88	 SCORE: 0.744	 ADD: 75
#
# epoch # 119	 SCORE: 0.834	 ADD: 79
#
# epoch # 203	 SCORE: 0.855	 ADD: 72
#
# epoch # 205	 SCORE: 0.869	 ADD: 75
#
# epoch # 230	 SCORE: 0.921	 ADD: 80
#
#
#
# REAL SCORE: 0.25
# INIT	 SCORE: 0.558
# epoch # 147	 SCORE: 0.574	 ADD: 82
#
# epoch # 180	 SCORE: 0.604	 ADD: 79
#
# epoch # 235	 SCORE: 0.607	 ADD: 78
#
# epoch # 249	 SCORE: 0.615	 ADD: 78
#
# epoch # 261	 SCORE: 0.685	 ADD: 70
#
# epoch # 378	 SCORE: 0.724	 ADD: 62
#
# epoch # 538	 SCORE: 0.740	 ADD: 64
#
# epoch # 606	 SCORE: 0.749	 ADD: 62
#
# epoch # 656	 SCORE: 0.761	 ADD: 66
#
# epoch # 673	 SCORE: 0.762	 ADD: 60
#
#
#
# REAL SCORE: 0.875
# INIT	 SCORE: 0.642
# epoch # 150	 SCORE: 0.682	 ADD: 82
#
# epoch # 214	 SCORE: 0.773	 ADD: 69
#
# epoch # 228	 SCORE: 0.857	 ADD: 61
#
# epoch # 283	 SCORE: 0.863	 ADD: 79
#
# epoch # 447	 SCORE: 0.878	 ADD: 45
#
# epoch # 460	 SCORE: 0.883	 ADD: 67
#
# epoch # 484	 SCORE: 0.898	 ADD: 76
#
# epoch # 579	 SCORE: 0.908	 ADD: 68
#
#
#
# REAL SCORE: 0.619047619048
# INIT	 SCORE: 0.575
# epoch # 90	 SCORE: 0.677	 ADD: 85
#
# epoch # 98	 SCORE: 0.728	 ADD: 82
#
# epoch # 129	 SCORE: 0.785	 ADD: 78
#
# epoch # 141	 SCORE: 0.791	 ADD: 82
#
# epoch # 180	 SCORE: 0.806	 ADD: 68
#
# epoch # 265	 SCORE: 0.809	 ADD: 65
#
# epoch # 549	 SCORE: 0.810	 ADD: 57
#
# epoch # 562	 SCORE: 0.815	 ADD: 59
#
# epoch # 598	 SCORE: 0.818	 ADD: 42
#
# epoch # 599	 SCORE: 0.854	 ADD: 66
#
# epoch # 648	 SCORE: 0.860	 ADD: 73
#
# epoch # 652	 SCORE: 0.871	 ADD: 55
#
# epoch # 697	 SCORE: 0.878	 ADD: 55
#
#
#
# REAL SCORE: 0.666666666667
# INIT	 SCORE: 0.689
# epoch # 98	 SCORE: 0.793	 ADD: 68
#
# epoch # 116	 SCORE: 0.798	 ADD: 83
#
# epoch # 141	 SCORE: 0.815	 ADD: 77
#
# epoch # 165	 SCORE: 0.816	 ADD: 75
#
# epoch # 198	 SCORE: 0.830	 ADD: 81
#
# epoch # 542	 SCORE: 0.843	 ADD: 53
#
# epoch # 656	 SCORE: 0.846	 ADD: 59
#
#
#
# REAL SCORE: 0.761904761905
# INIT	 SCORE: 0.682
# epoch # 111	 SCORE: 0.745	 ADD: 82
#
# epoch # 131	 SCORE: 0.774	 ADD: 84
#
# epoch # 154	 SCORE: 0.778	 ADD: 80
#
# epoch # 180	 SCORE: 0.805	 ADD: 66
#
# epoch # 233	 SCORE: 0.836	 ADD: 68
#
# epoch # 241	 SCORE: 0.909	 ADD: 62
#
# epoch # 259	 SCORE: 0.918	 ADD: 69
#
# epoch # 266	 SCORE: 0.923	 ADD: 75
#
# epoch # 272	 SCORE: 0.927	 ADD: 66
#
# epoch # 295	 SCORE: 0.932	 ADD: 76
#
#
#
# REAL SCORE: 0.7
# INIT	 SCORE: 0.680
# epoch # 74	 SCORE: 0.739	 ADD: 84
#
# epoch # 86	 SCORE: 0.758	 ADD: 78
#
# epoch # 167	 SCORE: 0.770	 ADD: 82
#
# epoch # 202	 SCORE: 0.789	 ADD: 70
#
# epoch # 243	 SCORE: 0.815	 ADD: 79
#
# epoch # 282	 SCORE: 0.829	 ADD: 75
#
# epoch # 285	 SCORE: 0.834	 ADD: 75
#
#
#
# REAL SCORE: 0.666666666667
# INIT	 SCORE: 0.653
# epoch # 80	 SCORE: 0.661	 ADD: 77
#
# epoch # 113	 SCORE: 0.836	 ADD: 68
#
# epoch # 127	 SCORE: 0.840	 ADD: 82
#
# epoch # 162	 SCORE: 0.848	 ADD: 82
#
# epoch # 283	 SCORE: 0.851	 ADD: 63
#
# epoch # 320	 SCORE: 0.865	 ADD: 63
#
# epoch # 345	 SCORE: 0.880	 ADD: 74
#
#
#
# REAL SCORE: 0.7
# INIT	 SCORE: 0.555
# epoch # 96	 SCORE: 0.583	 ADD: 82
#
# epoch # 173	 SCORE: 0.772	 ADD: 79
#
# epoch # 184	 SCORE: 0.783	 ADD: 67
#
# epoch # 321	 SCORE: 0.790	 ADD: 79
#
# epoch # 433	 SCORE: 0.793	 ADD: 78
#
#
#
# REAL SCORE: 0.3125
