# %%
import FeaturesLeak as fl
# %matplotlib inline

# %%
test_index =    [[ 5, 10, 13, 18, 44, 45, 56, 67, 70, 79, 90],
                 [ 0, 11, 16, 36, 41, 53, 59, 80, 83, 88],
                 [ 8, 22, 26, 31, 33, 55, 57, 65, 66, 85],
                 [ 1,  2, 35, 39, 42, 54, 63, 69, 76],
                 [24, 25, 27, 43, 49, 60, 61, 74, 78],
                 [ 7, 12, 32, 46, 50, 52, 75, 77, 87],
                 [ 6, 14, 29, 30, 48, 62, 81, 84, 89],
                 [ 3,  4, 15, 38, 40, 51, 58, 68, 73],
                 [17, 20, 21, 23, 37, 71, 82, 92, 93],
                 [ 9, 19, 28, 34, 47, 64, 72, 86, 91]]

index = []
for i in range(10):
    train_index = []
    for j in range(10):
         if i != j: train_index += test_index[j]
    index.append([train_index, test_index[i]])

# %%
grid_cv = fl.StratifiedKFold(n_splits=3,
                          shuffle=True,
                          random_state=0)

eval_cv = fl.StratifiedKFold(n_splits=3,
                          shuffle=True,
                          random_state=1)

# %%
myClass = fl.ChooseSubsection(grid_cv, eval_cv, 
                            k_tr            = 3,
                            k_bag           = 3,
                            test_size       = 0.1,
                            collect_n       = 20,
                            size_dim        = 264,
                            num_iteration   = 300,
                            learning_rate   = 0.5,
                            print_log       = True,
                            max_vec         = -1)

# %%
myClass.init_data()

# %%
myClass.get_seed_result(index)
# Out:
# INIT	 SCORE: 0.689
# epoch # 45	 SCORE: 0.769	 ADD: 78
#
# epoch # 58	 SCORE: 0.831	 ADD: 62
#
# epoch # 68	 SCORE: 0.831	 ADD: 76
#
# epoch # 88	 SCORE: 0.857	 ADD: 68
#
# epoch # 140	 SCORE: 0.860	 ADD: 61
#
# epoch # 167	 SCORE: 0.862	 ADD: 56
#
# epoch # 268	 SCORE: 0.869	 ADD: 55
#
# epoch # 289	 SCORE: 0.872	 ADD: 71
#
#
#
# REAL SCORE: 0.816666666667
# INIT	 SCORE: 0.500
# epoch # 58	 SCORE: 0.618	 ADD: 81
#
# epoch # 81	 SCORE: 0.691	 ADD: 79
#
# epoch # 101	 SCORE: 0.760	 ADD: 80
#
# epoch # 121	 SCORE: 0.762	 ADD: 79
#
# epoch # 126	 SCORE: 0.781	 ADD: 61
#
# epoch # 173	 SCORE: 0.838	 ADD: 66
#
#
#
# REAL SCORE: 0.9
# INIT	 SCORE: 0.796
# epoch # 59	 SCORE: 0.828	 ADD: 85
#
#
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.572
# epoch # 23	 SCORE: 0.617	 ADD: 80
#
# epoch # 33	 SCORE: 0.677	 ADD: 79
#
# epoch # 72	 SCORE: 0.733	 ADD: 70
#
# epoch # 77	 SCORE: 0.739	 ADD: 68
#
# epoch # 100	 SCORE: 0.757	 ADD: 76
#
#
#
# REAL SCORE: 0.875
# INIT	 SCORE: 0.606
# epoch # 87	 SCORE: 0.637	 ADD: 81
#
# epoch # 97	 SCORE: 0.695	 ADD: 68
#
# epoch # 103	 SCORE: 0.705	 ADD: 62
#
# epoch # 142	 SCORE: 0.713	 ADD: 71
#
# epoch # 264	 SCORE: 0.735	 ADD: 53
#
# epoch # 287	 SCORE: 0.747	 ADD: 73
#
#
#
# REAL SCORE: 0.5
# INIT	 SCORE: 0.622
# epoch # 24	 SCORE: 0.625	 ADD: 83
#
# epoch # 43	 SCORE: 0.687	 ADD: 73
#
# epoch # 88	 SCORE: 0.750	 ADD: 77
#
# epoch # 93	 SCORE: 0.783	 ADD: 65
#
# epoch # 121	 SCORE: 0.793	 ADD: 64
